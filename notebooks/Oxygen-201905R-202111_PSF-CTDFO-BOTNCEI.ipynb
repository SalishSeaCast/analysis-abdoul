# %% [markdown]
# ## Oxygen, compare 202111 to 201905R

# %%
import cmocean.cm as cm
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
import pandas as pd
# import statfieldodels.api as sm
import xarray as xr

from salishsea_tools import viz_tools

# %% [markdown]
# Bot data from 2011 - 2019
# PSF data from 2015 - 2017??

# %%
field = 'Dissolved Oxygen'
obsn = 'Oxygen_Dissolved'
modn = 'mod_dissolved_oxygen'
vmax = 500 #420
vmin = 0 #30
dbin = 10
scale = 360 #260

cmap = 'pink_r'#cm.rain #cm.ice_r #'ocean_r' #'pink_r'

# %%
foramt = "{:.3}"
myformat = {'bias': foramt, 'rmse': foramt, 'crmse':foramt, 'swillmott': foramt, 'slopedev': foramt, 'const': foramt,
                         'systematic': foramt, 'nonsystematic':foramt, 
                    'spread': foramt}

def use_f_2(x):
    return "%.2f" % x

# %%
with xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask201702.nc') as mesh:
    deptht = mesh.gdept_1d[0].values
bathy = xr.open_dataset('/home/sallen/MEOPAR/grid/bathymetry_202108.nc')

# %%
def bias(df, obs, mod):
    diffy = df[mod] - df[obs]
    return diffy.count(), diffy.mean()

# %%
def rmse(df, obs, mod):
    return (np.sqrt(((df[mod] - df[obs])**2).mean()))

# %%
def crmse(rmse, bias):
    return (np.sqrt(rmse**2 - bias**2))

# %%
def swillmott(df, obs, mod):
    meanobs = df[obs].mean()
    return (((df[mod] - df[obs])**2).sum()
            /(( (df[mod] - meanobs).abs() + (df[obs] - meanobs).abs() )**2).sum())

# %%
def slope_inter(df, obs, mod):
    X = df[obs]
    y = df[mod]
    X = sm.add_constant(X)

    # Fit and make the predictions by the model
    model = sm.OLS(y, X, missing='drop').fit()
    predictions = model.predict(X)
    
    nonsyst = np.sqrt(((y - predictions)**2).mean())
    systematic = np.sqrt(((predictions - df[obs])**2).mean())
    return model.params[obs], model.params['const'], systematic, nonsyst

# %%
def wolfram_perp(df, obsin, modin):
    
    mod = np.array(df[modin][(df[modin] == df[modin]) & (df[obsin] == df[obsin])])
    obs = np.array(df[obsin][(df[modin] == df[modin]) & (df[obsin] == df[obsin])])
    
    n = mod.shape[0]

    y2s = (mod**2).sum()
    ys = mod.sum()
    x2s = (obs**2).sum()
    xs = obs.sum()
    xys = (mod * obs).sum()
    B = 0.5 * ( (y2s - ys**2/n) - (x2s - xs**2/n)) / (xs * ys/n - xys)
    b1 = -B + np.sqrt(B*B + 1)
    a1 = (ys - b1*xs)/n
    predictions = a1 + b1 * df[obsin]
    
    nonsyst = np.sqrt(((df[modin] - predictions)**2).mean())
    systematic = np.sqrt(((predictions - df[obsin])**2).mean())

    return a1, b1, systematic, nonsyst

# %%
def spread(df, obs, mod):
    return 1 - ((df[mod] - df[mod].mean())**2).mean() / ((df[obs] - df[obs].mean())**2).mean()

# %%
def read_pieces(pieces):
    temp1 = pd.read_csv(pieces[0])
    for piece in pieces[1:]:
        nextpiece = pd.read_csv(piece)
        if 'ferry' in piece:
            nextpiece['k'] = 0
        temp1 = pd.concat([temp1, nextpiece], ignore_index=True)
    return temp1

# %%
def plot_and_stats(temp1, name, idepth, jdepth, fig, ax, whichdepths, reverse, string, boxes=False, box=None, boxname=None):
    if boxes:
        corn = box
        select = temp1[(temp1.k >= idepth) & (temp1.k <= jdepth) &
                              (temp1.j >= corn[0]) & (temp1.j <= corn[1]) &
                              (temp1.i >= corn[2]) & (temp1.i <= corn[3]) &
                              (temp1[obsn] == temp1[obsn])]
        shift_text = 0.94
    else:
        select = temp1[(temp1.k >= idepth) & (temp1.k < jdepth) & (temp1[obsn] == temp1[obsn])]
        shift_text = 1
    
    if reverse:
        one = modn
        two = obsn
    else:
        one = obsn
        two = modn
    
    counts, xedges, yedges, color = ax.hist2d(select[one], 
                                              select[two], 
                                           bins=np.arange(vmin, vmax, dbin), norm=LogNorm(), cmap=cmap);
    fig.colorbar(color, ax=ax)
   
    number, tbias = bias(select, one, two)
    trmse = rmse(select, one, two)
    tcrmse = crmse(trmse, tbias)
    tswillmott = swillmott(select, one, two)
#    m, c, syst, nonsyst = slope_inter(select, one, two)
    a1, b1, syst, nonsyst = wolfram_perp(select, one, two)
    tspread = spread(select, one, two)
    ax.plot([vmin, vmax], [vmin, vmax], 'k-');
    xr = np.arange(vmin, vmax, 0.5)
#    ax.plot(xr, c + m * xr, 'r-');
    ax.plot(xr, a1 + b1 * xr, 'r-')
    sc = scale/12
    sh = 2*sc-1
    bot = scale
    top = bot + 2*sh
    ax.arrow(sc+vmin, bot+vmin, 0, sh-np.abs(tbias)/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(sc+vmin, top+vmin, 0, -sh+np.abs(tbias)/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(2*sc+vmin, bot+vmin, 0, sh-syst/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(2*sc+vmin, top+vmin, 0, -sh+syst/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(3*sc+vmin, bot+vmin, 0, sh-nonsyst/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(3*sc+vmin, top+vmin, 0, -sh+nonsyst/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True);
    Cp2 = {'number': number,
            'bias': tbias,
          'rmse': trmse,
           'crmse': tcrmse,
          'swillmott': tswillmott,
          'slopedev': 1-b1,
          'const': a1,
          'systematic': syst,
          'nonsystematic': nonsyst,
          'spread': tspread}
    ax.text(0.8*sc+vmin, 0.9*bot*shift_text+vmin, 'bias', rotation=90)
    ax.text(1.8*sc+vmin, 0.72*bot*shift_text+vmin-shift_text, 'systematic', rotation=90)
    ax.text(2.8*sc+vmin, 0.6*bot*shift_text+vmin-shift_text, 'non-systematic', rotation=90)
    
    ax.set_title(f'{name}, {field} {whichdepths}{string}');
    dCp2 = pd.DataFrame(data=Cp2, index=[name])

    ax.set_ylabel('Model (µmol/L)')
    ax.set_xlabel('Obs (µmol/L)')
    return dCp2, counts

# %%
def highlight_max_min(s):
    '''
    highlight the maximum in a Series yellow.
    '''

    is_max = abs(s) == abs(s).max()
    is_min = abs(s) == abs(s).min()
    color = []
    for v, v2 in zip(is_max, is_min):
        if v:
            color.append('red')
        elif v2:
            color.append('darkgreen')
        else:
            color.append('black')
    return ['color: %s' % color[i] for i in range(len(is_max))]

# %%
def plot_allyears(years, years_psf, years_pug, years_ctdfo, years_ncei, years_onc, years_ferry, idepth, jdepth, whichdepths, reverse=False):
    if reverse:
        string = '_reverse'
    else:
        string = ''
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    startyear = years[0] #min(years[0], years_psf[0], years_pug[0])#, years_onc[0])
    endyear = years [-1] #max(years[-1], years_psf[-1], years_pug[-1])#, years_onc[-1])
    fig.suptitle(f'Year {startyear}-{endyear}')
    pieces1 = []
    for year in years:
        pieces1.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_bot_{year}0101_{year}1231.csv')
    for year in years_psf:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_psf_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_pugts_{year}0101_{year}1231.csv')
    for year in years_ctdfo:
        pieces1.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_201905R_ctd_from_dfo_{year}0101_{year}1231.csv')
    for year in years_ncei:
        pieces1.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_201905R_bot_from_ncei_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_onc_{year}0101_{year}1231.csv')
    for year in years_ferry:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_ferry_{year}0101_{year}1231.csv')
    temp1 = read_pieces(pieces1)
    d201905, counts1 = plot_and_stats(temp1, '201905R', idepth, jdepth, fig, axs[0], whichdepths, reverse, string)
    
    pieces2 = []
    for year in years:
        pieces2.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_bot_{year}0101_{year}1231.csv')
    for year in years_psf:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_psf_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_pugts_{year}0101_{year}1231.csv')
    for year in years_ctdfo:
        pieces2.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_202111_ctd_from_dfo_{year}0101_{year}1231.csv')
    for year in years_ncei:
        pieces2.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_202111_bot_from_ncei_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_onc_{year}0101_{year}1231.csv')
    for year in years_ferry:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_ferry_{year}0101_{year}1231.csv')
    temp2 = read_pieces(pieces2)
    d202111, counts2 = plot_and_stats(temp2, '202111', idepth, jdepth, fig, axs[1], whichdepths, reverse, string)

    alltogether = pd.concat([d201905, d202111], axis=0)
    
    fig.savefig(f'{whichdepths}_{field}{string}_201905_202111_for_allyears.png')
    
    f = open(f'./{whichdepths}_{field}{string}_201905_202111_for_allyears_table.tex', 'w')
    f.write(alltogether.to_latex(column_format='lcccccccccc', 
            formatters=["{:d}".format, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2]))
    f.close()
    return alltogether, counts1, counts2

# %% [markdown]
# ## All Depths

# %%
idepth = 0
jdepth = 39

results, counts1, counts2 = plot_allyears([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
                                          , [2015, 2016, 2017], []
                                          , [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
                                          , [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
                                       , [] #   , [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
                                       , [] #   , [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
                                          , idepth, jdepth, 'alldepths')
results.style.format(myformat).apply(highlight_max_min)
# Out:
# <style type="text/css">
# #T_1acba_row0_col0, #T_1acba_row0_col1, #T_1acba_row0_col2, #T_1acba_row0_col3, #T_1acba_row0_col4, #T_1acba_row0_col6, #T_1acba_row0_col7, #T_1acba_row0_col8, #T_1acba_row1_col5, #T_1acba_row1_col9 {
#   color: red;
# }
# #T_1acba_row0_col5, #T_1acba_row0_col9, #T_1acba_row1_col0, #T_1acba_row1_col1, #T_1acba_row1_col2, #T_1acba_row1_col3, #T_1acba_row1_col4, #T_1acba_row1_col6, #T_1acba_row1_col7, #T_1acba_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_1acba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1acba_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_1acba_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_1acba_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_1acba_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_1acba_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_1acba_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_1acba_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_1acba_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_1acba_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_1acba_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1acba_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_1acba_row0_col0" class="data row0 col0" >908528</td>
#       <td id="T_1acba_row0_col1" class="data row0 col1" >-32.0</td>
#       <td id="T_1acba_row0_col2" class="data row0 col2" >43.6</td>
#       <td id="T_1acba_row0_col3" class="data row0 col3" >29.6</td>
#       <td id="T_1acba_row0_col4" class="data row0 col4" >0.14</td>
#       <td id="T_1acba_row0_col5" class="data row0 col5" >-0.123</td>
#       <td id="T_1acba_row0_col6" class="data row0 col6" >-53.3</td>
#       <td id="T_1acba_row0_col7" class="data row0 col7" >32.6</td>
#       <td id="T_1acba_row0_col8" class="data row0 col8" >30.8</td>
#       <td id="T_1acba_row0_col9" class="data row0 col9" >-0.223</td>
#     </tr>
#     <tr>
#       <th id="T_1acba_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_1acba_row1_col0" class="data row1 col0" >908525</td>
#       <td id="T_1acba_row1_col1" class="data row1 col1" >-4.04</td>
#       <td id="T_1acba_row1_col2" class="data row1 col2" >25.3</td>
#       <td id="T_1acba_row1_col3" class="data row1 col3" >25.0</td>
#       <td id="T_1acba_row1_col4" class="data row1 col4" >0.0656</td>
#       <td id="T_1acba_row1_col5" class="data row1 col5" >0.149</td>
#       <td id="T_1acba_row1_col6" class="data row1 col6" >21.8</td>
#       <td id="T_1acba_row1_col7" class="data row1 col7" >9.02</td>
#       <td id="T_1acba_row1_col8" class="data row1 col8" >22.1</td>
#       <td id="T_1acba_row1_col9" class="data row1 col9" >0.249</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Top 5 m

# %%
idepth = 0
jdepth = 5

results, counts1, counts2 = plot_allyears([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
                                            , [2015, 2016, 2017]
                                          , [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
                                          , [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
                                       , [] 
                                       , [], 
                                          idepth, jdepth, 'top5m')
results.style.format(myformat).apply(highlight_max_min)
# Out:
# <style type="text/css">
# #T_cef8d_row0_col0, #T_cef8d_row0_col1, #T_cef8d_row0_col2, #T_cef8d_row0_col3, #T_cef8d_row0_col4, #T_cef8d_row0_col8, #T_cef8d_row1_col5, #T_cef8d_row1_col6, #T_cef8d_row1_col7, #T_cef8d_row1_col9 {
#   color: red;
# }
# #T_cef8d_row0_col5, #T_cef8d_row0_col6, #T_cef8d_row0_col7, #T_cef8d_row0_col9, #T_cef8d_row1_col0, #T_cef8d_row1_col1, #T_cef8d_row1_col2, #T_cef8d_row1_col3, #T_cef8d_row1_col4, #T_cef8d_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_cef8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cef8d_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_cef8d_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_cef8d_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_cef8d_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_cef8d_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_cef8d_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_cef8d_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_cef8d_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_cef8d_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_cef8d_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cef8d_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_cef8d_row0_col0" class="data row0 col0" >20624</td>
#       <td id="T_cef8d_row0_col1" class="data row0 col1" >-16.4</td>
#       <td id="T_cef8d_row0_col2" class="data row0 col2" >45.9</td>
#       <td id="T_cef8d_row0_col3" class="data row0 col3" >42.8</td>
#       <td id="T_cef8d_row0_col4" class="data row0 col4" >0.179</td>
#       <td id="T_cef8d_row0_col5" class="data row0 col5" >0.0511</td>
#       <td id="T_cef8d_row0_col6" class="data row0 col6" >-2.1</td>
#       <td id="T_cef8d_row0_col7" class="data row0 col7" >16.6</td>
#       <td id="T_cef8d_row0_col8" class="data row0 col8" >41.7</td>
#       <td id="T_cef8d_row0_col9" class="data row0 col9" >0.0719</td>
#     </tr>
#     <tr>
#       <th id="T_cef8d_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_cef8d_row1_col0" class="data row1 col0" >20621</td>
#       <td id="T_cef8d_row1_col1" class="data row1 col1" >-13.5</td>
#       <td id="T_cef8d_row1_col2" class="data row1 col2" >41.0</td>
#       <td id="T_cef8d_row1_col3" class="data row1 col3" >38.7</td>
#       <td id="T_cef8d_row1_col4" class="data row1 col4" >0.161</td>
#       <td id="T_cef8d_row1_col5" class="data row1 col5" >0.205</td>
#       <td id="T_cef8d_row1_col6" class="data row1 col6" >43.7</td>
#       <td id="T_cef8d_row1_col7" class="data row1 col7" >17.9</td>
#       <td id="T_cef8d_row1_col8" class="data row1 col8" >33.7</td>
#       <td id="T_cef8d_row1_col9" class="data row1 col9" >0.29</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Below 5 m

# %%
idepth = 5
jdepth = 39

results, counts1, counts2 = plot_allyears([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
                                            , [2015, 2016, 2017]
                                          , [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
                                          , [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
                                       , [] 
                                       , [], 
                                          idepth, jdepth, 'below5m')
results.style.format(myformat).apply(highlight_max_min)
# Out:
# <style type="text/css">
# #T_db8a9_row0_col0, #T_db8a9_row0_col1, #T_db8a9_row0_col2, #T_db8a9_row0_col3, #T_db8a9_row0_col4, #T_db8a9_row0_col6, #T_db8a9_row0_col7, #T_db8a9_row0_col8, #T_db8a9_row1_col0, #T_db8a9_row1_col5, #T_db8a9_row1_col9 {
#   color: red;
# }
# #T_db8a9_row0_col5, #T_db8a9_row0_col9, #T_db8a9_row1_col1, #T_db8a9_row1_col2, #T_db8a9_row1_col3, #T_db8a9_row1_col4, #T_db8a9_row1_col6, #T_db8a9_row1_col7, #T_db8a9_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_db8a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db8a9_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_db8a9_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_db8a9_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_db8a9_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_db8a9_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_db8a9_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_db8a9_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_db8a9_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_db8a9_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_db8a9_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db8a9_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_db8a9_row0_col0" class="data row0 col0" >887904</td>
#       <td id="T_db8a9_row0_col1" class="data row0 col1" >-32.3</td>
#       <td id="T_db8a9_row0_col2" class="data row0 col2" >43.5</td>
#       <td id="T_db8a9_row0_col3" class="data row0 col3" >29.2</td>
#       <td id="T_db8a9_row0_col4" class="data row0 col4" >0.153</td>
#       <td id="T_db8a9_row0_col5" class="data row0 col5" >-0.124</td>
#       <td id="T_db8a9_row0_col6" class="data row0 col6" >-53.5</td>
#       <td id="T_db8a9_row0_col7" class="data row0 col7" >32.9</td>
#       <td id="T_db8a9_row0_col8" class="data row0 col8" >30.4</td>
#       <td id="T_db8a9_row0_col9" class="data row0 col9" >-0.223</td>
#     </tr>
#     <tr>
#       <th id="T_db8a9_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_db8a9_row1_col0" class="data row1 col0" >887904</td>
#       <td id="T_db8a9_row1_col1" class="data row1 col1" >-3.82</td>
#       <td id="T_db8a9_row1_col2" class="data row1 col2" >24.8</td>
#       <td id="T_db8a9_row1_col3" class="data row1 col3" >24.5</td>
#       <td id="T_db8a9_row1_col4" class="data row1 col4" >0.0702</td>
#       <td id="T_db8a9_row1_col5" class="data row1 col5" >0.155</td>
#       <td id="T_db8a9_row1_col6" class="data row1 col6" >22.6</td>
#       <td id="T_db8a9_row1_col7" class="data row1 col7" >8.83</td>
#       <td id="T_db8a9_row1_col8" class="data row1 col8" >21.6</td>
#       <td id="T_db8a9_row1_col9" class="data row1 col9" >0.256</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Regionals

# %%
def stats_only(temp1, name, idepth, jdepth, corn, boxname):
    select = temp1[(temp1.k >= idepth) & (temp1.k <= jdepth) &
                              (temp1.j >= corn[0]) & (temp1.j <= corn[1]) &
                              (temp1.i >= corn[2]) & (temp1.i <= corn[3])]
    number, tbias = bias(select, obsn, modn)
    if number > 0:
        trmse = rmse(select, obsn, modn)
        tcrmse = crmse(trmse, tbias)
        tswillmott = swillmott(select, obsn, modn)
        a1, b1, syst, nonsyst = wolfram_perp(select, obsn, modn)
        tspread = spread(select, obsn, modn)
        Cp2 = {'number': number,
            'bias': tbias,
          'rmse': trmse,
          'crmse': tcrmse,
          'swillmott': tswillmott,
          'slopedev': 1-b1,
          'const': a1,
          'systematic': syst,
          'nonsystematic': nonsyst,
          'spread': tspread,
          'region': boxname}
        dCp2 = pd.DataFrame(data=Cp2, index=[name])
    else:
        dCp2 = 0
    return number, dCp2

# %%
def stats_allregions(years, years_psf, years_pug, years_ctdfo, years_ncei, years_onc, years_ferry, idepth, jdepth, whichdepths):
    pieces1 = []
    for year in years:
        pieces1.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_bot_{year}0101_{year}1231.csv'
             )
    for year in years_psf:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_psf_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_pugts_{year}0101_{year}1231.csv')
    for year in years_ctdfo:
        pieces1.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_201905R_ctd_from_dfo_{year}0101_{year}1231.csv')
    for year in years_ncei:
        pieces1.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_201905R_bot_from_ncei_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_onc_{year}0101_{year}1231.csv')    
    for year in years_ferry:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_ferry_{year}0101_{year}1231.csv')    
    temp1 = read_pieces(pieces1)
    
    number, alltogether = stats_only(temp1, '201905R', idepth, jdepth, boxes[0], boxnames[0])
    for boxname, corn in zip(boxnames[1:], boxes[1:]):
        number, d201905 = stats_only(temp1, '201905R', idepth, jdepth, corn, boxname)
        if number > 0:
            alltogether = pd.concat([alltogether, d201905], axis=0)

    pieces2 = []
    for year in years:
        pieces2.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_bot_{year}0101_{year}1231.csv'
             )
    for year in years_psf:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_psf_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_pugts_{year}0101_{year}1231.csv')
    for year in years_ctdfo:
        pieces2.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_202111_ctd_from_dfo_{year}0101_{year}1231.csv')
    for year in years_ncei:
        pieces2.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_202111_bot_from_ncei_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_onc_{year}0101_{year}1231.csv')
    for year in years_ferry:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_ferry_{year}0101_{year}1231.csv')
    temp2 = read_pieces(pieces2)
   
    for boxname, corn in zip(boxnames, boxes):
        number, d202111 = stats_only(temp2, '202111', idepth, jdepth, corn, boxname)
        if number > 0:
            alltogether = pd.concat([alltogether, d202111], axis=0)
    f = open(f'./{whichdepths}_{field}_201905_202111_for_allregions_table.tex', 'w')
    f.write(alltogether.to_latex(column_format='lccccccccccl', 
            formatters=["{:d}".format, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, str.upper]))
    f.close()
    return number, alltogether

# %%
def stats_and_plot(years, years_psf, years_pug, years_ctdfo, years_ncei, years_onc, years_ferry, idepth, jdepth, box, boxname, whichdepths):
    fig, axs = plt.subplots(1, 4, figsize=(20, 4))
    fig.suptitle(f'{boxname} Year {years[0]}-{years[-1]}')
    
    pieces1 = []
    for year in years:
        pieces1.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_bot_{year}0101_{year}1231.csv'
             )
    for year in years_psf:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_psf_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_pugts_{year}0101_{year}1231.csv')
    for year in years_ctdfo:
        pieces1.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_201905R_ctd_from_dfo_{year}0101_{year}1231.csv')
    for year in years_ncei:
        pieces1.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_201905R_bot_from_ncei_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_onc_{year}0101_{year}1231.csv')   
    for year in years_ferry:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_ferry_{year}0101_{year}1231.csv')   
    temp1 = read_pieces(pieces1)
    
    alltogether, counts = plot_and_stats(temp1, '201905R', idepth, jdepth, fig, axs[0], whichdepths, False, '', boxes=True, box=box, boxname=boxname)

    pieces2 = []
    for year in years:
        pieces2.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_bot_{year}0101_{year}1231.csv'
             )
    for year in years_psf:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_psf_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_pugts_{year}0101_{year}1231.csv')
    for year in years_ctdfo:
        pieces2.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_202111_ctd_from_dfo_{year}0101_{year}1231.csv')
    for year in years_ncei:
        pieces2.append(
            f'/ocean/atall/MOAD/ObsModel/202111/ObsModel_202111_bot_from_ncei_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_onc_{year}0101_{year}1231.csv')
    for year in years_ferry:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_ferry_{year}0101_{year}1231.csv')
    temp2 = read_pieces(pieces2)
    d202111, counts = plot_and_stats(temp2, '202111', idepth, jdepth, fig, axs[1], whichdepths, False, '', boxes=True, box=box, boxname=boxname)
    
    plot_profiles(temp1, temp2, axs[2], axs[3], box, boxname)
    
    
    alltogether = pd.concat([alltogether, d202111], axis=0)

# %%
def plot_profiles(temp1, temp2, ax, ax2, box, boxname):

    corn = box
    temp1['diff'] = temp1[modn] - temp1[obsn]
    select = temp1[(temp1.k >= idepth) & (temp1.k <= jdepth) &
                              (temp1.j >= corn[0]) & (temp1.j <= corn[1]) &
                              (temp1.i >= corn[2]) & (temp1.i <= corn[3]) &
                              (temp1[obsn] == temp1[obsn])]
    ks = (select.groupby('k')[obsn].mean().index[:])
    ax.plot(select.groupby('k')[obsn].mean(), deptht[ks], 'o-', c='tab:green', label='Observations')
    ax.plot(select.groupby('k')[modn].mean(), deptht[ks], 'o-', c='tab:blue', label='201905')
    ax2.plot(select.groupby('k')['diff'].mean(), deptht[ks], '-', c='tab:blue', label='201905')
    ax.fill_betweenx(deptht[ks], select[['k', modn]].groupby('k').quantile(q=0.25)[modn], select[['k', modn]].groupby('k').quantile(q=0.75)[modn], alpha=0.2, color='tab:blue')
    ax2.fill_betweenx(deptht[ks], select[['k', 'diff']].groupby('k').quantile(q=0.25)['diff'], select[['k', 'diff']].groupby('k').quantile(q=0.75)['diff'], alpha=0.2, color='tab:blue')
    
    temp2['diff'] = temp2[modn] - temp2[obsn]
    select = temp2[(temp2.k >= idepth) & (temp2.k <= jdepth) &
                              (temp2.j >= corn[0]) & (temp2.j <= corn[1]) &
                              (temp2.i >= corn[2]) & (temp2.i <= corn[3]) &
                              (temp2[obsn] == temp2[obsn])]
    
    ax.plot(select.groupby('k')[modn].mean(), deptht[ks], 'o-', c='tab:orange', label='202111')
    ax2.plot(select.groupby('k')['diff'].mean(), deptht[ks], '-', c='tab:orange', label='202111')
    ax.fill_betweenx(deptht[ks], select[['k', modn]].groupby('k').quantile(q=0.25)[modn], select[['k', modn]].groupby('k').quantile(q=0.75)[modn], alpha=0.2, color='tab:orange')
    ax.fill_betweenx(deptht[ks], select[['k', obsn]].groupby('k').quantile(q=0.25)[obsn], select[['k', obsn]].groupby('k').quantile(q=0.75)[obsn], alpha=0.2, color='tab:orange')
    ax2.fill_betweenx(deptht[ks], select[['k', 'diff']].groupby('k').quantile(q=0.25)['diff'], select[['k', 'diff']].groupby('k').quantile(q=0.75)['diff'], alpha=0.2, color='tab:orange')
    
    ax.invert_yaxis()
    ax2.invert_yaxis()
    
    ax.legend()
    ax2.legend()
    ax.set_title(f'{field} Profiles')
    ax2.set_title(f'{field} Difference Profiles')
    ax2.grid();
    ax.set_ylabel('Depth (m)')
    ax2.set_ylabel('Depth (m)')
    ax.set_xlabel('DO (µmol/L)')
    ax2.set_xlabel('DO (µmol/L)')

# %%
def plot_box(ax, corn, colour):
    ax.plot([corn[2], corn[3], corn[3], corn[2], corn[2]], 
            [corn[0], corn[0], corn[1], corn[1], corn[0]], '-', color=colour)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 9))
mycmap = cm.deep
mycmap.set_bad('grey')
ax.pcolormesh(bathy['Bathymetry'], cmap=mycmap)
viz_tools.set_aspect(ax);
SoG_center = [450, 550, 200, 300]
plot_box(ax, SoG_center, 'b')
SoG_north = [650, 730, 100, 200]
plot_box(ax, SoG_north, 'g')
SoG_south = [320, 380, 280, 350]
plot_box(ax, SoG_south, 'k')
Haro_Boundary = [290, 350, 210, 280]
plot_box(ax, Haro_Boundary, 'g')
JdF_east = [200, 290, 150, 260]
plot_box(ax, JdF_east, 'b')
JdF_west = [250, 425, 25, 125]
plot_box(ax, JdF_west, 'k')
Saanich_Inlet = [330, 390, 180, 220]
plot_box(ax, Saanich_Inlet, 'm')
#PS_main = [20, 150, 200, 280]
PS_main = [0, 150, 100, 280]
plot_box(ax, PS_main, 'k')
Hood_Canal = [68, 150, 100, 190]
plot_box(ax, Hood_Canal, 'm')
Fraser_plume = [380, 460, 260, 330]
plot_box(ax, Fraser_plume, 'm')
SS_all = [0, 898, 0, 398]
#boxes = [SS_all, SoG_south,SoG_center, SoG_north, PS_main, Haro_Boundary, JdF_west, JdF_east]
#boxnames = ['SS_all','SoG_south', 'SoG_center', 'SoG_north', 'PS_main', 'Haro_Boundary',
#           'JdF_west', 'JdF_east']
boxes = [SS_all, SoG_south,SoG_center, SoG_north, PS_main, Haro_Boundary, JdF_west, JdF_east, Hood_Canal, Saanich_Inlet, Fraser_plume ]
boxnames = ['SS_all','SoG_south', 'SoG_center', 'SoG_north', 'Haro_Boundary',
           'JdF_west', 'JdF_east', 'PS_main', 'Hood_Canal','Saanich_Inlet', 'Fraser_plume']

# %% [markdown]
# ## All Depths

# %%
idepth = 0
jdepth = 39

number, results = stats_allregions([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
                           [2015, 2016, 2017], [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
                           , [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], 
                           [],
                           idepth, jdepth, 'alldepths')
for boxname in boxnames:
    if number > 0:
        print(f'\033[1m{boxname}\033[1m')
        display(results[results.region == boxname].loc[:, results.columns != 'region'].style.format(myformat).apply(highlight_max_min))
# Out:
# SS_all
# <style type="text/css">
# #T_66fcf_row0_col0, #T_66fcf_row0_col1, #T_66fcf_row0_col2, #T_66fcf_row0_col3, #T_66fcf_row0_col4, #T_66fcf_row0_col6, #T_66fcf_row0_col7, #T_66fcf_row0_col8, #T_66fcf_row1_col5, #T_66fcf_row1_col9 {
#   color: red;
# }
# #T_66fcf_row0_col5, #T_66fcf_row0_col9, #T_66fcf_row1_col0, #T_66fcf_row1_col1, #T_66fcf_row1_col2, #T_66fcf_row1_col3, #T_66fcf_row1_col4, #T_66fcf_row1_col6, #T_66fcf_row1_col7, #T_66fcf_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_66fcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66fcf_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_66fcf_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_66fcf_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_66fcf_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_66fcf_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_66fcf_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_66fcf_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_66fcf_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_66fcf_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_66fcf_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66fcf_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_66fcf_row0_col0" class="data row0 col0" >908528</td>
#       <td id="T_66fcf_row0_col1" class="data row0 col1" >-32.0</td>
#       <td id="T_66fcf_row0_col2" class="data row0 col2" >43.6</td>
#       <td id="T_66fcf_row0_col3" class="data row0 col3" >29.6</td>
#       <td id="T_66fcf_row0_col4" class="data row0 col4" >0.14</td>
#       <td id="T_66fcf_row0_col5" class="data row0 col5" >-0.123</td>
#       <td id="T_66fcf_row0_col6" class="data row0 col6" >-53.3</td>
#       <td id="T_66fcf_row0_col7" class="data row0 col7" >32.6</td>
#       <td id="T_66fcf_row0_col8" class="data row0 col8" >30.8</td>
#       <td id="T_66fcf_row0_col9" class="data row0 col9" >-0.226</td>
#     </tr>
#     <tr>
#       <th id="T_66fcf_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_66fcf_row1_col0" class="data row1 col0" >908525</td>
#       <td id="T_66fcf_row1_col1" class="data row1 col1" >-4.04</td>
#       <td id="T_66fcf_row1_col2" class="data row1 col2" >25.3</td>
#       <td id="T_66fcf_row1_col3" class="data row1 col3" >25.0</td>
#       <td id="T_66fcf_row1_col4" class="data row1 col4" >0.0656</td>
#       <td id="T_66fcf_row1_col5" class="data row1 col5" >0.149</td>
#       <td id="T_66fcf_row1_col6" class="data row1 col6" >21.8</td>
#       <td id="T_66fcf_row1_col7" class="data row1 col7" >9.02</td>
#       <td id="T_66fcf_row1_col8" class="data row1 col8" >22.1</td>
#       <td id="T_66fcf_row1_col9" class="data row1 col9" >0.259</td>
#     </tr>
#   </tbody>
# </table>
# SoG_south
# <style type="text/css">
# #T_9db1e_row0_col0, #T_9db1e_row0_col1, #T_9db1e_row0_col2, #T_9db1e_row0_col3, #T_9db1e_row0_col4, #T_9db1e_row0_col5, #T_9db1e_row0_col6, #T_9db1e_row0_col7, #T_9db1e_row0_col8, #T_9db1e_row0_col9, #T_9db1e_row1_col0 {
#   color: red;
# }
# #T_9db1e_row1_col1, #T_9db1e_row1_col2, #T_9db1e_row1_col3, #T_9db1e_row1_col4, #T_9db1e_row1_col5, #T_9db1e_row1_col6, #T_9db1e_row1_col7, #T_9db1e_row1_col8, #T_9db1e_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_9db1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9db1e_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_9db1e_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_9db1e_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_9db1e_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_9db1e_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_9db1e_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_9db1e_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_9db1e_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_9db1e_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_9db1e_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9db1e_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_9db1e_row0_col0" class="data row0 col0" >42207</td>
#       <td id="T_9db1e_row0_col1" class="data row0 col1" >-22.5</td>
#       <td id="T_9db1e_row0_col2" class="data row0 col2" >32.7</td>
#       <td id="T_9db1e_row0_col3" class="data row0 col3" >23.7</td>
#       <td id="T_9db1e_row0_col4" class="data row0 col4" >0.11</td>
#       <td id="T_9db1e_row0_col5" class="data row0 col5" >-0.291</td>
#       <td id="T_9db1e_row0_col6" class="data row0 col6" >-81.9</td>
#       <td id="T_9db1e_row0_col7" class="data row0 col7" >25.8</td>
#       <td id="T_9db1e_row0_col8" class="data row0 col8" >23.7</td>
#       <td id="T_9db1e_row0_col9" class="data row0 col9" >-0.595</td>
#     </tr>
#     <tr>
#       <th id="T_9db1e_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_9db1e_row1_col0" class="data row1 col0" >42207</td>
#       <td id="T_9db1e_row1_col1" class="data row1 col1" >-7.03</td>
#       <td id="T_9db1e_row1_col2" class="data row1 col2" >18.0</td>
#       <td id="T_9db1e_row1_col3" class="data row1 col3" >16.6</td>
#       <td id="T_9db1e_row1_col4" class="data row1 col4" >0.0448</td>
#       <td id="T_9db1e_row1_col5" class="data row1 col5" >0.00471</td>
#       <td id="T_9db1e_row1_col6" class="data row1 col6" >-6.07</td>
#       <td id="T_9db1e_row1_col7" class="data row1 col7" >7.03</td>
#       <td id="T_9db1e_row1_col8" class="data row1 col8" >16.5</td>
#       <td id="T_9db1e_row1_col9" class="data row1 col9" >0.00314</td>
#     </tr>
#   </tbody>
# </table>
# SoG_center
# <style type="text/css">
# #T_62edb_row0_col0, #T_62edb_row0_col1, #T_62edb_row0_col2, #T_62edb_row0_col3, #T_62edb_row0_col4, #T_62edb_row0_col5, #T_62edb_row0_col6, #T_62edb_row0_col7, #T_62edb_row0_col8, #T_62edb_row0_col9, #T_62edb_row1_col0 {
#   color: red;
# }
# #T_62edb_row1_col1, #T_62edb_row1_col2, #T_62edb_row1_col3, #T_62edb_row1_col4, #T_62edb_row1_col5, #T_62edb_row1_col6, #T_62edb_row1_col7, #T_62edb_row1_col8, #T_62edb_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_62edb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62edb_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_62edb_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_62edb_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_62edb_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_62edb_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_62edb_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_62edb_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_62edb_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_62edb_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_62edb_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62edb_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_62edb_row0_col0" class="data row0 col0" >170990</td>
#       <td id="T_62edb_row0_col1" class="data row0 col1" >-38.1</td>
#       <td id="T_62edb_row0_col2" class="data row0 col2" >45.3</td>
#       <td id="T_62edb_row0_col3" class="data row0 col3" >24.5</td>
#       <td id="T_62edb_row0_col4" class="data row0 col4" >0.176</td>
#       <td id="T_62edb_row0_col5" class="data row0 col5" >-0.198</td>
#       <td id="T_62edb_row0_col6" class="data row0 col6" >-71.9</td>
#       <td id="T_62edb_row0_col7" class="data row0 col7" >39.2</td>
#       <td id="T_62edb_row0_col8" class="data row0 col8" >25.3</td>
#       <td id="T_62edb_row0_col9" class="data row0 col9" >-0.297</td>
#     </tr>
#     <tr>
#       <th id="T_62edb_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_62edb_row1_col0" class="data row1 col0" >170990</td>
#       <td id="T_62edb_row1_col1" class="data row1 col1" >-3.07</td>
#       <td id="T_62edb_row1_col2" class="data row1 col2" >18.1</td>
#       <td id="T_62edb_row1_col3" class="data row1 col3" >17.9</td>
#       <td id="T_62edb_row1_col4" class="data row1 col4" >0.0421</td>
#       <td id="T_62edb_row1_col5" class="data row1 col5" >0.0815</td>
#       <td id="T_62edb_row1_col6" class="data row1 col6" >10.8</td>
#       <td id="T_62edb_row1_col7" class="data row1 col7" >4.89</td>
#       <td id="T_62edb_row1_col8" class="data row1 col8" >16.8</td>
#       <td id="T_62edb_row1_col9" class="data row1 col9" >0.187</td>
#     </tr>
#   </tbody>
# </table>
# SoG_north
# <style type="text/css">
# #T_a3ceb_row0_col0, #T_a3ceb_row0_col1, #T_a3ceb_row0_col2, #T_a3ceb_row0_col3, #T_a3ceb_row0_col4, #T_a3ceb_row0_col6, #T_a3ceb_row0_col7, #T_a3ceb_row0_col8, #T_a3ceb_row1_col0, #T_a3ceb_row1_col5, #T_a3ceb_row1_col9 {
#   color: red;
# }
# #T_a3ceb_row0_col5, #T_a3ceb_row0_col9, #T_a3ceb_row1_col1, #T_a3ceb_row1_col2, #T_a3ceb_row1_col3, #T_a3ceb_row1_col4, #T_a3ceb_row1_col6, #T_a3ceb_row1_col7, #T_a3ceb_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_a3ceb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3ceb_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_a3ceb_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_a3ceb_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_a3ceb_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_a3ceb_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_a3ceb_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_a3ceb_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_a3ceb_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_a3ceb_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_a3ceb_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3ceb_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_a3ceb_row0_col0" class="data row0 col0" >77779</td>
#       <td id="T_a3ceb_row0_col1" class="data row0 col1" >-44.0</td>
#       <td id="T_a3ceb_row0_col2" class="data row0 col2" >49.6</td>
#       <td id="T_a3ceb_row0_col3" class="data row0 col3" >22.8</td>
#       <td id="T_a3ceb_row0_col4" class="data row0 col4" >0.204</td>
#       <td id="T_a3ceb_row0_col5" class="data row0 col5" >-0.116</td>
#       <td id="T_a3ceb_row0_col6" class="data row0 col6" >-63.2</td>
#       <td id="T_a3ceb_row0_col7" class="data row0 col7" >44.4</td>
#       <td id="T_a3ceb_row0_col8" class="data row0 col8" >23.5</td>
#       <td id="T_a3ceb_row0_col9" class="data row0 col9" >-0.308</td>
#     </tr>
#     <tr>
#       <th id="T_a3ceb_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_a3ceb_row1_col0" class="data row1 col0" >77779</td>
#       <td id="T_a3ceb_row1_col1" class="data row1 col1" >-1.8</td>
#       <td id="T_a3ceb_row1_col2" class="data row1 col2" >21.2</td>
#       <td id="T_a3ceb_row1_col3" class="data row1 col3" >21.1</td>
#       <td id="T_a3ceb_row1_col4" class="data row1 col4" >0.0636</td>
#       <td id="T_a3ceb_row1_col5" class="data row1 col5" >0.225</td>
#       <td id="T_a3ceb_row1_col6" class="data row1 col6" >35.5</td>
#       <td id="T_a3ceb_row1_col7" class="data row1 col7" >10.9</td>
#       <td id="T_a3ceb_row1_col8" class="data row1 col8" >16.5</td>
#       <td id="T_a3ceb_row1_col9" class="data row1 col9" >0.318</td>
#     </tr>
#   </tbody>
# </table>
# Haro_Boundary
# <style type="text/css">
# #T_a5081_row0_col0, #T_a5081_row0_col1, #T_a5081_row0_col2, #T_a5081_row0_col3, #T_a5081_row0_col4, #T_a5081_row0_col6, #T_a5081_row0_col7, #T_a5081_row0_col8, #T_a5081_row1_col0, #T_a5081_row1_col5, #T_a5081_row1_col9 {
#   color: red;
# }
# #T_a5081_row0_col5, #T_a5081_row0_col9, #T_a5081_row1_col1, #T_a5081_row1_col2, #T_a5081_row1_col3, #T_a5081_row1_col4, #T_a5081_row1_col6, #T_a5081_row1_col7, #T_a5081_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_a5081">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5081_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_a5081_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_a5081_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_a5081_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_a5081_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_a5081_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_a5081_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_a5081_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_a5081_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_a5081_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5081_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_a5081_row0_col0" class="data row0 col0" >6699</td>
#       <td id="T_a5081_row0_col1" class="data row0 col1" >-30.4</td>
#       <td id="T_a5081_row0_col2" class="data row0 col2" >47.4</td>
#       <td id="T_a5081_row0_col3" class="data row0 col3" >36.4</td>
#       <td id="T_a5081_row0_col4" class="data row0 col4" >0.172</td>
#       <td id="T_a5081_row0_col5" class="data row0 col5" >-0.092</td>
#       <td id="T_a5081_row0_col6" class="data row0 col6" >-49.1</td>
#       <td id="T_a5081_row0_col7" class="data row0 col7" >30.8</td>
#       <td id="T_a5081_row0_col8" class="data row0 col8" >37.8</td>
#       <td id="T_a5081_row0_col9" class="data row0 col9" >-0.0963</td>
#     </tr>
#     <tr>
#       <th id="T_a5081_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_a5081_row1_col0" class="data row1 col0" >6699</td>
#       <td id="T_a5081_row1_col1" class="data row1 col1" >-14.7</td>
#       <td id="T_a5081_row1_col2" class="data row1 col2" >34.1</td>
#       <td id="T_a5081_row1_col3" class="data row1 col3" >30.8</td>
#       <td id="T_a5081_row1_col4" class="data row1 col4" >0.121</td>
#       <td id="T_a5081_row1_col5" class="data row1 col5" >0.211</td>
#       <td id="T_a5081_row1_col6" class="data row1 col6" >28.4</td>
#       <td id="T_a5081_row1_col7" class="data row1 col7" >18.7</td>
#       <td id="T_a5081_row1_col8" class="data row1 col8" >26.0</td>
#       <td id="T_a5081_row1_col9" class="data row1 col9" >0.366</td>
#     </tr>
#   </tbody>
# </table>
# JdF_west
# <style type="text/css">
# #T_7dd76_row0_col0, #T_7dd76_row0_col1, #T_7dd76_row0_col2, #T_7dd76_row0_col3, #T_7dd76_row0_col4, #T_7dd76_row0_col5, #T_7dd76_row0_col6, #T_7dd76_row0_col7, #T_7dd76_row0_col8, #T_7dd76_row0_col9, #T_7dd76_row1_col0 {
#   color: red;
# }
# #T_7dd76_row1_col1, #T_7dd76_row1_col2, #T_7dd76_row1_col3, #T_7dd76_row1_col4, #T_7dd76_row1_col5, #T_7dd76_row1_col6, #T_7dd76_row1_col7, #T_7dd76_row1_col8, #T_7dd76_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_7dd76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7dd76_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_7dd76_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_7dd76_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_7dd76_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_7dd76_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_7dd76_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_7dd76_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_7dd76_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_7dd76_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_7dd76_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7dd76_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_7dd76_row0_col0" class="data row0 col0" >51058</td>
#       <td id="T_7dd76_row0_col1" class="data row0 col1" >-9.84</td>
#       <td id="T_7dd76_row0_col2" class="data row0 col2" >19.6</td>
#       <td id="T_7dd76_row0_col3" class="data row0 col3" >16.9</td>
#       <td id="T_7dd76_row0_col4" class="data row0 col4" >0.0465</td>
#       <td id="T_7dd76_row0_col5" class="data row0 col5" >-0.126</td>
#       <td id="T_7dd76_row0_col6" class="data row0 col6" >-33.5</td>
#       <td id="T_7dd76_row0_col7" class="data row0 col7" >11.3</td>
#       <td id="T_7dd76_row0_col8" class="data row0 col8" >17.1</td>
#       <td id="T_7dd76_row0_col9" class="data row0 col9" >-0.269</td>
#     </tr>
#     <tr>
#       <th id="T_7dd76_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_7dd76_row1_col0" class="data row1 col0" >51058</td>
#       <td id="T_7dd76_row1_col1" class="data row1 col1" >-5.88</td>
#       <td id="T_7dd76_row1_col2" class="data row1 col2" >15.9</td>
#       <td id="T_7dd76_row1_col3" class="data row1 col3" >14.8</td>
#       <td id="T_7dd76_row1_col4" class="data row1 col4" >0.0333</td>
#       <td id="T_7dd76_row1_col5" class="data row1 col5" >-0.0474</td>
#       <td id="T_7dd76_row1_col6" class="data row1 col6" >-14.7</td>
#       <td id="T_7dd76_row1_col7" class="data row1 col7" >6.23</td>
#       <td id="T_7dd76_row1_col8" class="data row1 col8" >15.0</td>
#       <td id="T_7dd76_row1_col9" class="data row1 col9" >-0.102</td>
#     </tr>
#   </tbody>
# </table>
# JdF_east
# <style type="text/css">
# #T_cb781_row0_col0, #T_cb781_row0_col2, #T_cb781_row0_col3, #T_cb781_row0_col4, #T_cb781_row0_col6, #T_cb781_row0_col8, #T_cb781_row1_col0, #T_cb781_row1_col1, #T_cb781_row1_col5, #T_cb781_row1_col7, #T_cb781_row1_col9 {
#   color: red;
# }
# #T_cb781_row0_col1, #T_cb781_row0_col5, #T_cb781_row0_col7, #T_cb781_row0_col9, #T_cb781_row1_col2, #T_cb781_row1_col3, #T_cb781_row1_col4, #T_cb781_row1_col6, #T_cb781_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_cb781">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb781_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_cb781_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_cb781_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_cb781_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_cb781_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_cb781_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_cb781_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_cb781_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_cb781_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_cb781_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb781_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_cb781_row0_col0" class="data row0 col0" >38326</td>
#       <td id="T_cb781_row0_col1" class="data row0 col1" >-9.03</td>
#       <td id="T_cb781_row0_col2" class="data row0 col2" >26.0</td>
#       <td id="T_cb781_row0_col3" class="data row0 col3" >24.4</td>
#       <td id="T_cb781_row0_col4" class="data row0 col4" >0.0453</td>
#       <td id="T_cb781_row0_col5" class="data row0 col5" >0.0104</td>
#       <td id="T_cb781_row0_col6" class="data row0 col6" >-7.44</td>
#       <td id="T_cb781_row0_col7" class="data row0 col7" >9.05</td>
#       <td id="T_cb781_row0_col8" class="data row0 col8" >24.2</td>
#       <td id="T_cb781_row0_col9" class="data row0 col9" >0.00142</td>
#     </tr>
#     <tr>
#       <th id="T_cb781_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_cb781_row1_col0" class="data row1 col0" >38326</td>
#       <td id="T_cb781_row1_col1" class="data row1 col1" >-9.35</td>
#       <td id="T_cb781_row1_col2" class="data row1 col2" >23.9</td>
#       <td id="T_cb781_row1_col3" class="data row1 col3" >22.0</td>
#       <td id="T_cb781_row1_col4" class="data row1 col4" >0.0383</td>
#       <td id="T_cb781_row1_col5" class="data row1 col5" >0.0184</td>
#       <td id="T_cb781_row1_col6" class="data row1 col6" >-6.53</td>
#       <td id="T_cb781_row1_col7" class="data row1 col7" >9.42</td>
#       <td id="T_cb781_row1_col8" class="data row1 col8" >21.8</td>
#       <td id="T_cb781_row1_col9" class="data row1 col9" >0.0253</td>
#     </tr>
#   </tbody>
# </table>
# PS_main
# <style type="text/css">
# #T_b8225_row0_col0, #T_b8225_row0_col1, #T_b8225_row0_col2, #T_b8225_row0_col3, #T_b8225_row0_col4, #T_b8225_row0_col7, #T_b8225_row0_col8, #T_b8225_row1_col0, #T_b8225_row1_col5, #T_b8225_row1_col6, #T_b8225_row1_col9 {
#   color: red;
# }
# #T_b8225_row0_col5, #T_b8225_row0_col6, #T_b8225_row0_col9, #T_b8225_row1_col1, #T_b8225_row1_col2, #T_b8225_row1_col3, #T_b8225_row1_col4, #T_b8225_row1_col7, #T_b8225_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_b8225">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8225_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_b8225_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_b8225_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_b8225_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_b8225_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_b8225_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_b8225_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_b8225_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_b8225_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_b8225_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8225_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_b8225_row0_col0" class="data row0 col0" >31142</td>
#       <td id="T_b8225_row0_col1" class="data row0 col1" >-10.2</td>
#       <td id="T_b8225_row0_col2" class="data row0 col2" >21.5</td>
#       <td id="T_b8225_row0_col3" class="data row0 col3" >19.0</td>
#       <td id="T_b8225_row0_col4" class="data row0 col4" >0.0443</td>
#       <td id="T_b8225_row0_col5" class="data row0 col5" >0.0369</td>
#       <td id="T_b8225_row0_col6" class="data row0 col6" >-3.51</td>
#       <td id="T_b8225_row0_col7" class="data row0 col7" >10.4</td>
#       <td id="T_b8225_row0_col8" class="data row0 col8" >18.5</td>
#       <td id="T_b8225_row0_col9" class="data row0 col9" >0.0654</td>
#     </tr>
#     <tr>
#       <th id="T_b8225_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_b8225_row1_col0" class="data row1 col0" >31142</td>
#       <td id="T_b8225_row1_col1" class="data row1 col1" >-9.31</td>
#       <td id="T_b8225_row1_col2" class="data row1 col2" >19.7</td>
#       <td id="T_b8225_row1_col3" class="data row1 col3" >17.3</td>
#       <td id="T_b8225_row1_col4" class="data row1 col4" >0.0383</td>
#       <td id="T_b8225_row1_col5" class="data row1 col5" >0.0732</td>
#       <td id="T_b8225_row1_col6" class="data row1 col6" >3.95</td>
#       <td id="T_b8225_row1_col7" class="data row1 col7" >10.1</td>
#       <td id="T_b8225_row1_col8" class="data row1 col8" >16.3</td>
#       <td id="T_b8225_row1_col9" class="data row1 col9" >0.133</td>
#     </tr>
#   </tbody>
# </table>
# Hood_Canal
# <style type="text/css">
# #T_e2af6_row0_col0, #T_e2af6_row0_col8, #T_e2af6_row1_col0, #T_e2af6_row1_col1, #T_e2af6_row1_col2, #T_e2af6_row1_col3, #T_e2af6_row1_col4, #T_e2af6_row1_col5, #T_e2af6_row1_col6, #T_e2af6_row1_col7, #T_e2af6_row1_col9 {
#   color: red;
# }
# #T_e2af6_row0_col1, #T_e2af6_row0_col2, #T_e2af6_row0_col3, #T_e2af6_row0_col4, #T_e2af6_row0_col5, #T_e2af6_row0_col6, #T_e2af6_row0_col7, #T_e2af6_row0_col9, #T_e2af6_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_e2af6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2af6_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_e2af6_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_e2af6_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_e2af6_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_e2af6_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_e2af6_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_e2af6_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_e2af6_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_e2af6_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_e2af6_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2af6_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_e2af6_row0_col0" class="data row0 col0" >971</td>
#       <td id="T_e2af6_row0_col1" class="data row0 col1" >-6.6</td>
#       <td id="T_e2af6_row0_col2" class="data row0 col2" >58.0</td>
#       <td id="T_e2af6_row0_col3" class="data row0 col3" >57.6</td>
#       <td id="T_e2af6_row0_col4" class="data row0 col4" >0.1</td>
#       <td id="T_e2af6_row0_col5" class="data row0 col5" >0.153</td>
#       <td id="T_e2af6_row0_col6" class="data row0 col6" >21.2</td>
#       <td id="T_e2af6_row0_col7" class="data row0 col7" >16.9</td>
#       <td id="T_e2af6_row0_col8" class="data row0 col8" >51.7</td>
#       <td id="T_e2af6_row0_col9" class="data row0 col9" >0.24</td>
#     </tr>
#     <tr>
#       <th id="T_e2af6_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_e2af6_row1_col0" class="data row1 col0" >971</td>
#       <td id="T_e2af6_row1_col1" class="data row1 col1" >-10.9</td>
#       <td id="T_e2af6_row1_col2" class="data row1 col2" >59.8</td>
#       <td id="T_e2af6_row1_col3" class="data row1 col3" >58.9</td>
#       <td id="T_e2af6_row1_col4" class="data row1 col4" >0.134</td>
#       <td id="T_e2af6_row1_col5" class="data row1 col5" >0.39</td>
#       <td id="T_e2af6_row1_col6" class="data row1 col6" >59.9</td>
#       <td id="T_e2af6_row1_col7" class="data row1 col7" >41.0</td>
#       <td id="T_e2af6_row1_col8" class="data row1 col8" >37.6</td>
#       <td id="T_e2af6_row1_col9" class="data row1 col9" >0.565</td>
#     </tr>
#   </tbody>
# </table>
# Saanich_Inlet
# <style type="text/css">
# #T_89ee6_row0_col0, #T_89ee6_row0_col8, #T_89ee6_row1_col0, #T_89ee6_row1_col1, #T_89ee6_row1_col2, #T_89ee6_row1_col3, #T_89ee6_row1_col4, #T_89ee6_row1_col5, #T_89ee6_row1_col6, #T_89ee6_row1_col7, #T_89ee6_row1_col9 {
#   color: red;
# }
# #T_89ee6_row0_col1, #T_89ee6_row0_col2, #T_89ee6_row0_col3, #T_89ee6_row0_col4, #T_89ee6_row0_col5, #T_89ee6_row0_col6, #T_89ee6_row0_col7, #T_89ee6_row0_col9, #T_89ee6_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_89ee6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89ee6_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_89ee6_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_89ee6_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_89ee6_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_89ee6_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_89ee6_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_89ee6_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_89ee6_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_89ee6_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_89ee6_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89ee6_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_89ee6_row0_col0" class="data row0 col0" >22270</td>
#       <td id="T_89ee6_row0_col1" class="data row0 col1" >21.6</td>
#       <td id="T_89ee6_row0_col2" class="data row0 col2" >67.0</td>
#       <td id="T_89ee6_row0_col3" class="data row0 col3" >63.4</td>
#       <td id="T_89ee6_row0_col4" class="data row0 col4" >0.196</td>
#       <td id="T_89ee6_row0_col5" class="data row0 col5" >0.452</td>
#       <td id="T_89ee6_row0_col6" class="data row0 col6" >90.8</td>
#       <td id="T_89ee6_row0_col7" class="data row0 col7" >48.4</td>
#       <td id="T_89ee6_row0_col8" class="data row0 col8" >39.4</td>
#       <td id="T_89ee6_row0_col9" class="data row0 col9" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_89ee6_row1_col0" class="data row1 col0" >22270</td>
#       <td id="T_89ee6_row1_col1" class="data row1 col1" >39.9</td>
#       <td id="T_89ee6_row1_col2" class="data row1 col2" >77.3</td>
#       <td id="T_89ee6_row1_col3" class="data row1 col3" >66.2</td>
#       <td id="T_89ee6_row1_col4" class="data row1 col4" >0.277</td>
#       <td id="T_89ee6_row1_col5" class="data row1 col5" >0.59</td>
#       <td id="T_89ee6_row1_col6" class="data row1 col6" >1.3e+02</td>
#       <td id="T_89ee6_row1_col7" class="data row1 col7" >69.2</td>
#       <td id="T_89ee6_row1_col8" class="data row1 col8" >28.8</td>
#       <td id="T_89ee6_row1_col9" class="data row1 col9" >0.775</td>
#     </tr>
#   </tbody>
# </table>
# Fraser_plume
# <style type="text/css">
# #T_29be1_row0_col0, #T_29be1_row0_col1, #T_29be1_row0_col2, #T_29be1_row0_col3, #T_29be1_row0_col4, #T_29be1_row0_col5, #T_29be1_row0_col6, #T_29be1_row0_col7, #T_29be1_row0_col8, #T_29be1_row0_col9, #T_29be1_row1_col0 {
#   color: red;
# }
# #T_29be1_row1_col1, #T_29be1_row1_col2, #T_29be1_row1_col3, #T_29be1_row1_col4, #T_29be1_row1_col5, #T_29be1_row1_col6, #T_29be1_row1_col7, #T_29be1_row1_col8, #T_29be1_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_29be1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29be1_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_29be1_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_29be1_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_29be1_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_29be1_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_29be1_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_29be1_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_29be1_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_29be1_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_29be1_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29be1_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_29be1_row0_col0" class="data row0 col0" >109516</td>
#       <td id="T_29be1_row0_col1" class="data row0 col1" >-33.7</td>
#       <td id="T_29be1_row0_col2" class="data row0 col2" >42.8</td>
#       <td id="T_29be1_row0_col3" class="data row0 col3" >26.3</td>
#       <td id="T_29be1_row0_col4" class="data row0 col4" >0.159</td>
#       <td id="T_29be1_row0_col5" class="data row0 col5" >-0.265</td>
#       <td id="T_29be1_row0_col6" class="data row0 col6" >-81.7</td>
#       <td id="T_29be1_row0_col7" class="data row0 col7" >35.8</td>
#       <td id="T_29be1_row0_col8" class="data row0 col8" >27.1</td>
#       <td id="T_29be1_row0_col9" class="data row0 col9" >-0.586</td>
#     </tr>
#     <tr>
#       <th id="T_29be1_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_29be1_row1_col0" class="data row1 col0" >109516</td>
#       <td id="T_29be1_row1_col1" class="data row1 col1" >-4.23</td>
#       <td id="T_29be1_row1_col2" class="data row1 col2" >20.2</td>
#       <td id="T_29be1_row1_col3" class="data row1 col3" >19.8</td>
#       <td id="T_29be1_row1_col4" class="data row1 col4" >0.0517</td>
#       <td id="T_29be1_row1_col5" class="data row1 col5" >0.0358</td>
#       <td id="T_29be1_row1_col6" class="data row1 col6" >2.26</td>
#       <td id="T_29be1_row1_col7" class="data row1 col7" >4.54</td>
#       <td id="T_29be1_row1_col8" class="data row1 col8" >19.4</td>
#       <td id="T_29be1_row1_col9" class="data row1 col9" >0.0532</td>
#     </tr>
#   </tbody>
# </table>

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
                [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
                [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], 
               [], 
               [],
               idepth, jdepth, SoG_south, 'SoG_south', 'alldepths')

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
                [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
                [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
                 [], 
               [],
               idepth, jdepth, SoG_center, 'SoG_center', 'alldepths')

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
               [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
               [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], [],
               idepth, jdepth, SoG_north, 'SoG_north', 'alldepths')

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
               [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
               [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], [],
               idepth, jdepth, Haro_Boundary, 'Haro_Boundary', 'alldepths')

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
               [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
               [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], [],
               idepth, jdepth, JdF_west, 'JdF_west', 'alldepths')

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
               [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
               [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], [],
               idepth, jdepth, JdF_east, 'JdF_east', 'alldepths')

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
               [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
               [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], [],
               idepth, jdepth, PS_main, 'PS_main', 'alldepths')

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
               [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
               [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], [],
               idepth, jdepth, Hood_Canal, 'Hood_Canal', 'alldepths')

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
               [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
               [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], [],
               idepth, jdepth, Saanich_Inlet, 'Saanich_Inlet', 'alldepths')

# %%
stats_and_plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], [2015, 2016, 2017], 
               [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
               [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], [],
               idepth, jdepth, Fraser_plume, 'Fraser_plume', 'alldepths')

# %% [markdown]
# ## Above 5 m

# %%
idepth = 0
jdepth = 5

number, results = stats_allregions([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
                           [], [2015, 2016, 2017], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
                           [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], 
                           [],
                           idepth, jdepth, 'top5m')
for boxname in boxnames:
    if number > 0:
        print(f'\033[1m{boxname}\033[1m')
        display(results[results.region == boxname].loc[:, results.columns != 'region'].style.format(myformat).apply(highlight_max_min))
# Out:
# SS_all
# <style type="text/css">
# #T_d9684_row0_col0, #T_d9684_row0_col1, #T_d9684_row0_col2, #T_d9684_row0_col3, #T_d9684_row0_col4, #T_d9684_row0_col8, #T_d9684_row1_col5, #T_d9684_row1_col6, #T_d9684_row1_col7, #T_d9684_row1_col9 {
#   color: red;
# }
# #T_d9684_row0_col5, #T_d9684_row0_col6, #T_d9684_row0_col7, #T_d9684_row0_col9, #T_d9684_row1_col0, #T_d9684_row1_col1, #T_d9684_row1_col2, #T_d9684_row1_col3, #T_d9684_row1_col4, #T_d9684_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_d9684">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9684_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_d9684_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_d9684_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_d9684_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_d9684_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_d9684_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_d9684_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_d9684_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_d9684_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_d9684_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9684_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_d9684_row0_col0" class="data row0 col0" >26598</td>
#       <td id="T_d9684_row0_col1" class="data row0 col1" >-15.7</td>
#       <td id="T_d9684_row0_col2" class="data row0 col2" >45.9</td>
#       <td id="T_d9684_row0_col3" class="data row0 col3" >43.1</td>
#       <td id="T_d9684_row0_col4" class="data row0 col4" >0.178</td>
#       <td id="T_d9684_row0_col5" class="data row0 col5" >0.0219</td>
#       <td id="T_d9684_row0_col6" class="data row0 col6" >-9.61</td>
#       <td id="T_d9684_row0_col7" class="data row0 col7" >15.7</td>
#       <td id="T_d9684_row0_col8" class="data row0 col8" >42.7</td>
#       <td id="T_d9684_row0_col9" class="data row0 col9" >0.0111</td>
#     </tr>
#     <tr>
#       <th id="T_d9684_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_d9684_row1_col0" class="data row1 col0" >26595</td>
#       <td id="T_d9684_row1_col1" class="data row1 col1" >-12.7</td>
#       <td id="T_d9684_row1_col2" class="data row1 col2" >40.9</td>
#       <td id="T_d9684_row1_col3" class="data row1 col3" >38.9</td>
#       <td id="T_d9684_row1_col4" class="data row1 col4" >0.159</td>
#       <td id="T_d9684_row1_col5" class="data row1 col5" >0.187</td>
#       <td id="T_d9684_row1_col6" class="data row1 col6" >39.1</td>
#       <td id="T_d9684_row1_col7" class="data row1 col7" >16.6</td>
#       <td id="T_d9684_row1_col8" class="data row1 col8" >34.4</td>
#       <td id="T_d9684_row1_col9" class="data row1 col9" >0.226</td>
#     </tr>
#   </tbody>
# </table>
# SoG_south
# <style type="text/css">
# #T_f2501_row0_col0, #T_f2501_row0_col1, #T_f2501_row0_col2, #T_f2501_row0_col3, #T_f2501_row0_col4, #T_f2501_row0_col8, #T_f2501_row1_col0, #T_f2501_row1_col5, #T_f2501_row1_col6, #T_f2501_row1_col7, #T_f2501_row1_col9 {
#   color: red;
# }
# #T_f2501_row0_col5, #T_f2501_row0_col6, #T_f2501_row0_col7, #T_f2501_row0_col9, #T_f2501_row1_col1, #T_f2501_row1_col2, #T_f2501_row1_col3, #T_f2501_row1_col4, #T_f2501_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_f2501">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2501_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_f2501_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_f2501_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_f2501_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_f2501_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_f2501_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_f2501_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_f2501_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_f2501_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_f2501_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2501_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_f2501_row0_col0" class="data row0 col0" >1317</td>
#       <td id="T_f2501_row0_col1" class="data row0 col1" >-12.4</td>
#       <td id="T_f2501_row0_col2" class="data row0 col2" >42.0</td>
#       <td id="T_f2501_row0_col3" class="data row0 col3" >40.2</td>
#       <td id="T_f2501_row0_col4" class="data row0 col4" >0.2</td>
#       <td id="T_f2501_row0_col5" class="data row0 col5" >-0.0817</td>
#       <td id="T_f2501_row0_col6" class="data row0 col6" >-34.2</td>
#       <td id="T_f2501_row0_col7" class="data row0 col7" >13.0</td>
#       <td id="T_f2501_row0_col8" class="data row0 col8" >41.7</td>
#       <td id="T_f2501_row0_col9" class="data row0 col9" >-0.0738</td>
#     </tr>
#     <tr>
#       <th id="T_f2501_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_f2501_row1_col0" class="data row1 col0" >1317</td>
#       <td id="T_f2501_row1_col1" class="data row1 col1" >-4.88</td>
#       <td id="T_f2501_row1_col2" class="data row1 col2" >34.4</td>
#       <td id="T_f2501_row1_col3" class="data row1 col3" >34.0</td>
#       <td id="T_f2501_row1_col4" class="data row1 col4" >0.179</td>
#       <td id="T_f2501_row1_col5" class="data row1 col5" >0.297</td>
#       <td id="T_f2501_row1_col6" class="data row1 col6" >74.3</td>
#       <td id="T_f2501_row1_col7" class="data row1 col7" >15.1</td>
#       <td id="T_f2501_row1_col8" class="data row1 col8" >27.3</td>
#       <td id="T_f2501_row1_col9" class="data row1 col9" >0.416</td>
#     </tr>
#   </tbody>
# </table>
# SoG_center
# <style type="text/css">
# #T_f3b46_row0_col0, #T_f3b46_row0_col1, #T_f3b46_row0_col2, #T_f3b46_row0_col3, #T_f3b46_row0_col4, #T_f3b46_row0_col8, #T_f3b46_row1_col0, #T_f3b46_row1_col5, #T_f3b46_row1_col6, #T_f3b46_row1_col7, #T_f3b46_row1_col9 {
#   color: red;
# }
# #T_f3b46_row0_col5, #T_f3b46_row0_col6, #T_f3b46_row0_col7, #T_f3b46_row0_col9, #T_f3b46_row1_col1, #T_f3b46_row1_col2, #T_f3b46_row1_col3, #T_f3b46_row1_col4, #T_f3b46_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_f3b46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3b46_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_f3b46_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_f3b46_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_f3b46_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_f3b46_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_f3b46_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_f3b46_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_f3b46_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_f3b46_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_f3b46_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3b46_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_f3b46_row0_col0" class="data row0 col0" >3513</td>
#       <td id="T_f3b46_row0_col1" class="data row0 col1" >-12.6</td>
#       <td id="T_f3b46_row0_col2" class="data row0 col2" >42.6</td>
#       <td id="T_f3b46_row0_col3" class="data row0 col3" >40.7</td>
#       <td id="T_f3b46_row0_col4" class="data row0 col4" >0.291</td>
#       <td id="T_f3b46_row0_col5" class="data row0 col5" >0.309</td>
#       <td id="T_f3b46_row0_col6" class="data row0 col6" >81.0</td>
#       <td id="T_f3b46_row0_col7" class="data row0 col7" >19.2</td>
#       <td id="T_f3b46_row0_col8" class="data row0 col8" >33.5</td>
#       <td id="T_f3b46_row0_col9" class="data row0 col9" >0.39</td>
#     </tr>
#     <tr>
#       <th id="T_f3b46_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_f3b46_row1_col0" class="data row1 col0" >3513</td>
#       <td id="T_f3b46_row1_col1" class="data row1 col1" >-7.81</td>
#       <td id="T_f3b46_row1_col2" class="data row1 col2" >38.1</td>
#       <td id="T_f3b46_row1_col3" class="data row1 col3" >37.3</td>
#       <td id="T_f3b46_row1_col4" class="data row1 col4" >0.269</td>
#       <td id="T_f3b46_row1_col5" class="data row1 col5" >0.477</td>
#       <td id="T_f3b46_row1_col6" class="data row1 col6" >1.37e+02</td>
#       <td id="T_f3b46_row1_col7" class="data row1 col7" >23.6</td>
#       <td id="T_f3b46_row1_col8" class="data row1 col8" >25.4</td>
#       <td id="T_f3b46_row1_col9" class="data row1 col9" >0.56</td>
#     </tr>
#   </tbody>
# </table>
# SoG_north
# <style type="text/css">
# #T_28b41_row0_col0, #T_28b41_row0_col1, #T_28b41_row0_col2, #T_28b41_row0_col3, #T_28b41_row0_col4, #T_28b41_row0_col5, #T_28b41_row0_col6, #T_28b41_row0_col7, #T_28b41_row0_col8, #T_28b41_row0_col9, #T_28b41_row1_col0 {
#   color: red;
# }
# #T_28b41_row1_col1, #T_28b41_row1_col2, #T_28b41_row1_col3, #T_28b41_row1_col4, #T_28b41_row1_col5, #T_28b41_row1_col6, #T_28b41_row1_col7, #T_28b41_row1_col8, #T_28b41_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_28b41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28b41_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_28b41_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_28b41_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_28b41_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_28b41_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_28b41_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_28b41_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_28b41_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_28b41_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_28b41_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28b41_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_28b41_row0_col0" class="data row0 col0" >1878</td>
#       <td id="T_28b41_row0_col1" class="data row0 col1" >-17.2</td>
#       <td id="T_28b41_row0_col2" class="data row0 col2" >51.7</td>
#       <td id="T_28b41_row0_col3" class="data row0 col3" >48.7</td>
#       <td id="T_28b41_row0_col4" class="data row0 col4" >0.309</td>
#       <td id="T_28b41_row0_col5" class="data row0 col5" >-0.408</td>
#       <td id="T_28b41_row0_col6" class="data row0 col6" >-1.3e+02</td>
#       <td id="T_28b41_row0_col7" class="data row0 col7" >25.3</td>
#       <td id="T_28b41_row0_col8" class="data row0 col8" >57.5</td>
#       <td id="T_28b41_row0_col9" class="data row0 col9" >-0.411</td>
#     </tr>
#     <tr>
#       <th id="T_28b41_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_28b41_row1_col0" class="data row1 col0" >1878</td>
#       <td id="T_28b41_row1_col1" class="data row1 col1" >-11.1</td>
#       <td id="T_28b41_row1_col2" class="data row1 col2" >43.5</td>
#       <td id="T_28b41_row1_col3" class="data row1 col3" >42.1</td>
#       <td id="T_28b41_row1_col4" class="data row1 col4" >0.274</td>
#       <td id="T_28b41_row1_col5" class="data row1 col5" >0.0384</td>
#       <td id="T_28b41_row1_col6" class="data row1 col6" >-0.524</td>
#       <td id="T_28b41_row1_col7" class="data row1 col7" >11.3</td>
#       <td id="T_28b41_row1_col8" class="data row1 col8" >41.3</td>
#       <td id="T_28b41_row1_col9" class="data row1 col9" >0.0701</td>
#     </tr>
#   </tbody>
# </table>
# Haro_Boundary
# <style type="text/css">
# #T_2bc1a_row0_col0, #T_2bc1a_row0_col1, #T_2bc1a_row0_col2, #T_2bc1a_row0_col3, #T_2bc1a_row0_col6, #T_2bc1a_row0_col8, #T_2bc1a_row1_col0, #T_2bc1a_row1_col4, #T_2bc1a_row1_col5, #T_2bc1a_row1_col7, #T_2bc1a_row1_col9 {
#   color: red;
# }
# #T_2bc1a_row0_col4, #T_2bc1a_row0_col5, #T_2bc1a_row0_col7, #T_2bc1a_row0_col9, #T_2bc1a_row1_col1, #T_2bc1a_row1_col2, #T_2bc1a_row1_col3, #T_2bc1a_row1_col6, #T_2bc1a_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_2bc1a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bc1a_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_2bc1a_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_2bc1a_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_2bc1a_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_2bc1a_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_2bc1a_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_2bc1a_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_2bc1a_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_2bc1a_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_2bc1a_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bc1a_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_2bc1a_row0_col0" class="data row0 col0" >958</td>
#       <td id="T_2bc1a_row0_col1" class="data row0 col1" >-26.5</td>
#       <td id="T_2bc1a_row0_col2" class="data row0 col2" >65.1</td>
#       <td id="T_2bc1a_row0_col3" class="data row0 col3" >59.5</td>
#       <td id="T_2bc1a_row0_col4" class="data row0 col4" >0.226</td>
#       <td id="T_2bc1a_row0_col5" class="data row0 col5" >-0.0438</td>
#       <td id="T_2bc1a_row0_col6" class="data row0 col6" >-38.3</td>
#       <td id="T_2bc1a_row0_col7" class="data row0 col7" >26.7</td>
#       <td id="T_2bc1a_row0_col8" class="data row0 col8" >60.7</td>
#       <td id="T_2bc1a_row0_col9" class="data row0 col9" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_2bc1a_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_2bc1a_row1_col0" class="data row1 col0" >958</td>
#       <td id="T_2bc1a_row1_col1" class="data row1 col1" >-26.2</td>
#       <td id="T_2bc1a_row1_col2" class="data row1 col2" >62.7</td>
#       <td id="T_2bc1a_row1_col3" class="data row1 col3" >56.9</td>
#       <td id="T_2bc1a_row1_col4" class="data row1 col4" >0.239</td>
#       <td id="T_2bc1a_row1_col5" class="data row1 col5" >0.226</td>
#       <td id="T_2bc1a_row1_col6" class="data row1 col6" >34.5</td>
#       <td id="T_2bc1a_row1_col7" class="data row1 col7" >30.6</td>
#       <td id="T_2bc1a_row1_col8" class="data row1 col8" >49.5</td>
#       <td id="T_2bc1a_row1_col9" class="data row1 col9" >0.513</td>
#     </tr>
#   </tbody>
# </table>
# JdF_west
# <style type="text/css">
# #T_09c99_row0_col0, #T_09c99_row0_col1, #T_09c99_row0_col2, #T_09c99_row0_col3, #T_09c99_row0_col4, #T_09c99_row0_col5, #T_09c99_row0_col6, #T_09c99_row0_col7, #T_09c99_row0_col8, #T_09c99_row0_col9, #T_09c99_row1_col0 {
#   color: red;
# }
# #T_09c99_row1_col1, #T_09c99_row1_col2, #T_09c99_row1_col3, #T_09c99_row1_col4, #T_09c99_row1_col5, #T_09c99_row1_col6, #T_09c99_row1_col7, #T_09c99_row1_col8, #T_09c99_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_09c99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09c99_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_09c99_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_09c99_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_09c99_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_09c99_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_09c99_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_09c99_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_09c99_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_09c99_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_09c99_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09c99_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_09c99_row0_col0" class="data row0 col0" >1126</td>
#       <td id="T_09c99_row0_col1" class="data row0 col1" >-6.64</td>
#       <td id="T_09c99_row0_col2" class="data row0 col2" >24.9</td>
#       <td id="T_09c99_row0_col3" class="data row0 col3" >24.0</td>
#       <td id="T_09c99_row0_col4" class="data row0 col4" >0.103</td>
#       <td id="T_09c99_row0_col5" class="data row0 col5" >-0.307</td>
#       <td id="T_09c99_row0_col6" class="data row0 col6" >-74.7</td>
#       <td id="T_09c99_row0_col7" class="data row0 col7" >12.7</td>
#       <td id="T_09c99_row0_col8" class="data row0 col8" >25.5</td>
#       <td id="T_09c99_row0_col9" class="data row0 col9" >-0.622</td>
#     </tr>
#     <tr>
#       <th id="T_09c99_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_09c99_row1_col0" class="data row1 col0" >1126</td>
#       <td id="T_09c99_row1_col1" class="data row1 col1" >-0.213</td>
#       <td id="T_09c99_row1_col2" class="data row1 col2" >19.4</td>
#       <td id="T_09c99_row1_col3" class="data row1 col3" >19.4</td>
#       <td id="T_09c99_row1_col4" class="data row1 col4" >0.081</td>
#       <td id="T_09c99_row1_col5" class="data row1 col5" >0.0174</td>
#       <td id="T_09c99_row1_col6" class="data row1 col6" >3.64</td>
#       <td id="T_09c99_row1_col7" class="data row1 col7" >0.651</td>
#       <td id="T_09c99_row1_col8" class="data row1 col8" >19.2</td>
#       <td id="T_09c99_row1_col9" class="data row1 col9" >0.0601</td>
#     </tr>
#   </tbody>
# </table>
# JdF_east
# <style type="text/css">
# #T_077fc_row0_col0, #T_077fc_row0_col2, #T_077fc_row0_col3, #T_077fc_row0_col4, #T_077fc_row0_col8, #T_077fc_row1_col0, #T_077fc_row1_col1, #T_077fc_row1_col5, #T_077fc_row1_col6, #T_077fc_row1_col7, #T_077fc_row1_col9 {
#   color: red;
# }
# #T_077fc_row0_col1, #T_077fc_row0_col5, #T_077fc_row0_col6, #T_077fc_row0_col7, #T_077fc_row0_col9, #T_077fc_row1_col2, #T_077fc_row1_col3, #T_077fc_row1_col4, #T_077fc_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_077fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_077fc_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_077fc_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_077fc_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_077fc_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_077fc_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_077fc_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_077fc_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_077fc_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_077fc_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_077fc_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_077fc_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_077fc_row0_col0" class="data row0 col0" >1358</td>
#       <td id="T_077fc_row0_col1" class="data row0 col1" >-5.64</td>
#       <td id="T_077fc_row0_col2" class="data row0 col2" >41.7</td>
#       <td id="T_077fc_row0_col3" class="data row0 col3" >41.3</td>
#       <td id="T_077fc_row0_col4" class="data row0 col4" >0.215</td>
#       <td id="T_077fc_row0_col5" class="data row0 col5" >-0.0387</td>
#       <td id="T_077fc_row0_col6" class="data row0 col6" >-15.0</td>
#       <td id="T_077fc_row0_col7" class="data row0 col7" >5.93</td>
#       <td id="T_077fc_row0_col8" class="data row0 col8" >42.1</td>
#       <td id="T_077fc_row0_col9" class="data row0 col9" >-0.0212</td>
#     </tr>
#     <tr>
#       <th id="T_077fc_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_077fc_row1_col0" class="data row1 col0" >1358</td>
#       <td id="T_077fc_row1_col1" class="data row1 col1" >-10.8</td>
#       <td id="T_077fc_row1_col2" class="data row1 col2" >35.9</td>
#       <td id="T_077fc_row1_col3" class="data row1 col3" >34.3</td>
#       <td id="T_077fc_row1_col4" class="data row1 col4" >0.177</td>
#       <td id="T_077fc_row1_col5" class="data row1 col5" >0.182</td>
#       <td id="T_077fc_row1_col6" class="data row1 col6" >33.2</td>
#       <td id="T_077fc_row1_col7" class="data row1 col7" >13.8</td>
#       <td id="T_077fc_row1_col8" class="data row1 col8" >30.6</td>
#       <td id="T_077fc_row1_col9" class="data row1 col9" >0.269</td>
#     </tr>
#   </tbody>
# </table>
# PS_main
# <style type="text/css">
# #T_3a14a_row0_col0, #T_3a14a_row0_col1, #T_3a14a_row0_col2, #T_3a14a_row0_col3, #T_3a14a_row0_col4, #T_3a14a_row0_col5, #T_3a14a_row0_col6, #T_3a14a_row0_col7, #T_3a14a_row0_col8, #T_3a14a_row0_col9, #T_3a14a_row1_col0 {
#   color: red;
# }
# #T_3a14a_row1_col1, #T_3a14a_row1_col2, #T_3a14a_row1_col3, #T_3a14a_row1_col4, #T_3a14a_row1_col5, #T_3a14a_row1_col6, #T_3a14a_row1_col7, #T_3a14a_row1_col8, #T_3a14a_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_3a14a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a14a_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_3a14a_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_3a14a_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_3a14a_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_3a14a_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_3a14a_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_3a14a_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_3a14a_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_3a14a_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_3a14a_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a14a_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_3a14a_row0_col0" class="data row0 col0" >1466</td>
#       <td id="T_3a14a_row0_col1" class="data row0 col1" >-12.2</td>
#       <td id="T_3a14a_row0_col2" class="data row0 col2" >25.7</td>
#       <td id="T_3a14a_row0_col3" class="data row0 col3" >22.6</td>
#       <td id="T_3a14a_row0_col4" class="data row0 col4" >0.0848</td>
#       <td id="T_3a14a_row0_col5" class="data row0 col5" >-0.118</td>
#       <td id="T_3a14a_row0_col6" class="data row0 col6" >-38.8</td>
#       <td id="T_3a14a_row0_col7" class="data row0 col7" >13.2</td>
#       <td id="T_3a14a_row0_col8" class="data row0 col8" >23.5</td>
#       <td id="T_3a14a_row0_col9" class="data row0 col9" >-0.206</td>
#     </tr>
#     <tr>
#       <th id="T_3a14a_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_3a14a_row1_col0" class="data row1 col0" >1466</td>
#       <td id="T_3a14a_row1_col1" class="data row1 col1" >-9.7</td>
#       <td id="T_3a14a_row1_col2" class="data row1 col2" >23.2</td>
#       <td id="T_3a14a_row1_col3" class="data row1 col3" >21.0</td>
#       <td id="T_3a14a_row1_col4" class="data row1 col4" >0.081</td>
#       <td id="T_3a14a_row1_col5" class="data row1 col5" >0.0681</td>
#       <td id="T_3a14a_row1_col6" class="data row1 col6" >5.64</td>
#       <td id="T_3a14a_row1_col7" class="data row1 col7" >10.1</td>
#       <td id="T_3a14a_row1_col8" class="data row1 col8" >20.2</td>
#       <td id="T_3a14a_row1_col9" class="data row1 col9" >0.169</td>
#     </tr>
#   </tbody>
# </table>
# Hood_Canal
# <style type="text/css">
# #T_47d65_row0_col0, #T_47d65_row0_col3, #T_47d65_row0_col6, #T_47d65_row0_col8, #T_47d65_row1_col0, #T_47d65_row1_col1, #T_47d65_row1_col2, #T_47d65_row1_col4, #T_47d65_row1_col5, #T_47d65_row1_col7, #T_47d65_row1_col9 {
#   color: red;
# }
# #T_47d65_row0_col1, #T_47d65_row0_col2, #T_47d65_row0_col4, #T_47d65_row0_col5, #T_47d65_row0_col7, #T_47d65_row0_col9, #T_47d65_row1_col3, #T_47d65_row1_col6, #T_47d65_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_47d65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47d65_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_47d65_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_47d65_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_47d65_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_47d65_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_47d65_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_47d65_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_47d65_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_47d65_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_47d65_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47d65_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_47d65_row0_col0" class="data row0 col0" >260</td>
#       <td id="T_47d65_row0_col1" class="data row0 col1" >-28.2</td>
#       <td id="T_47d65_row0_col2" class="data row0 col2" >78.8</td>
#       <td id="T_47d65_row0_col3" class="data row0 col3" >73.6</td>
#       <td id="T_47d65_row0_col4" class="data row0 col4" >0.24</td>
#       <td id="T_47d65_row0_col5" class="data row0 col5" >0.293</td>
#       <td id="T_47d65_row0_col6" class="data row0 col6" >56.5</td>
#       <td id="T_47d65_row0_col7" class="data row0 col7" >39.0</td>
#       <td id="T_47d65_row0_col8" class="data row0 col8" >60.6</td>
#       <td id="T_47d65_row0_col9" class="data row0 col9" >0.426</td>
#     </tr>
#     <tr>
#       <th id="T_47d65_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_47d65_row1_col0" class="data row1 col0" >260</td>
#       <td id="T_47d65_row1_col1" class="data row1 col1" >-55.5</td>
#       <td id="T_47d65_row1_col2" class="data row1 col2" >91.3</td>
#       <td id="T_47d65_row1_col3" class="data row1 col3" >72.4</td>
#       <td id="T_47d65_row1_col4" class="data row1 col4" >0.281</td>
#       <td id="T_47d65_row1_col5" class="data row1 col5" >0.33</td>
#       <td id="T_47d65_row1_col6" class="data row1 col6" >39.8</td>
#       <td id="T_47d65_row1_col7" class="data row1 col7" >63.3</td>
#       <td id="T_47d65_row1_col8" class="data row1 col8" >57.6</td>
#       <td id="T_47d65_row1_col9" class="data row1 col9" >0.552</td>
#     </tr>
#   </tbody>
# </table>
# Saanich_Inlet
# <style type="text/css">
# #T_84c83_row0_col0, #T_84c83_row0_col1, #T_84c83_row0_col2, #T_84c83_row0_col3, #T_84c83_row0_col8, #T_84c83_row1_col0, #T_84c83_row1_col4, #T_84c83_row1_col5, #T_84c83_row1_col6, #T_84c83_row1_col7, #T_84c83_row1_col9 {
#   color: red;
# }
# #T_84c83_row0_col4, #T_84c83_row0_col5, #T_84c83_row0_col6, #T_84c83_row0_col7, #T_84c83_row0_col9, #T_84c83_row1_col1, #T_84c83_row1_col2, #T_84c83_row1_col3, #T_84c83_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_84c83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84c83_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_84c83_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_84c83_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_84c83_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_84c83_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_84c83_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_84c83_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_84c83_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_84c83_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_84c83_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84c83_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_84c83_row0_col0" class="data row0 col0" >1223</td>
#       <td id="T_84c83_row0_col1" class="data row0 col1" >-27.1</td>
#       <td id="T_84c83_row0_col2" class="data row0 col2" >65.1</td>
#       <td id="T_84c83_row0_col3" class="data row0 col3" >59.2</td>
#       <td id="T_84c83_row0_col4" class="data row0 col4" >0.251</td>
#       <td id="T_84c83_row0_col5" class="data row0 col5" >0.145</td>
#       <td id="T_84c83_row0_col6" class="data row0 col6" >14.5</td>
#       <td id="T_84c83_row0_col7" class="data row0 col7" >28.9</td>
#       <td id="T_84c83_row0_col8" class="data row0 col8" >54.6</td>
#       <td id="T_84c83_row0_col9" class="data row0 col9" >0.308</td>
#     </tr>
#     <tr>
#       <th id="T_84c83_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_84c83_row1_col0" class="data row1 col0" >1223</td>
#       <td id="T_84c83_row1_col1" class="data row1 col1" >-25.3</td>
#       <td id="T_84c83_row1_col2" class="data row1 col2" >59.7</td>
#       <td id="T_84c83_row1_col3" class="data row1 col3" >54.1</td>
#       <td id="T_84c83_row1_col4" class="data row1 col4" >0.259</td>
#       <td id="T_84c83_row1_col5" class="data row1 col5" >0.423</td>
#       <td id="T_84c83_row1_col6" class="data row1 col6" >95.9</td>
#       <td id="T_84c83_row1_col7" class="data row1 col7" >38.7</td>
#       <td id="T_84c83_row1_col8" class="data row1 col8" >38.9</td>
#       <td id="T_84c83_row1_col9" class="data row1 col9" >0.593</td>
#     </tr>
#   </tbody>
# </table>
# Fraser_plume
# <style type="text/css">
# #T_e4f4e_row0_col0, #T_e4f4e_row0_col1, #T_e4f4e_row0_col2, #T_e4f4e_row0_col3, #T_e4f4e_row0_col4, #T_e4f4e_row0_col8, #T_e4f4e_row1_col0, #T_e4f4e_row1_col5, #T_e4f4e_row1_col6, #T_e4f4e_row1_col7, #T_e4f4e_row1_col9 {
#   color: red;
# }
# #T_e4f4e_row0_col5, #T_e4f4e_row0_col6, #T_e4f4e_row0_col7, #T_e4f4e_row0_col9, #T_e4f4e_row1_col1, #T_e4f4e_row1_col2, #T_e4f4e_row1_col3, #T_e4f4e_row1_col4, #T_e4f4e_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_e4f4e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4f4e_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_e4f4e_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_e4f4e_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_e4f4e_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_e4f4e_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_e4f4e_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_e4f4e_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_e4f4e_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_e4f4e_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_e4f4e_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4f4e_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_e4f4e_row0_col0" class="data row0 col0" >2531</td>
#       <td id="T_e4f4e_row0_col1" class="data row0 col1" >-12.6</td>
#       <td id="T_e4f4e_row0_col2" class="data row0 col2" >49.9</td>
#       <td id="T_e4f4e_row0_col3" class="data row0 col3" >48.3</td>
#       <td id="T_e4f4e_row0_col4" class="data row0 col4" >0.291</td>
#       <td id="T_e4f4e_row0_col5" class="data row0 col5" >0.235</td>
#       <td id="T_e4f4e_row0_col6" class="data row0 col6" >56.7</td>
#       <td id="T_e4f4e_row0_col7" class="data row0 col7" >17.8</td>
#       <td id="T_e4f4e_row0_col8" class="data row0 col8" >42.1</td>
#       <td id="T_e4f4e_row0_col9" class="data row0 col9" >-0.0771</td>
#     </tr>
#     <tr>
#       <th id="T_e4f4e_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_e4f4e_row1_col0" class="data row1 col0" >2531</td>
#       <td id="T_e4f4e_row1_col1" class="data row1 col1" >-10.7</td>
#       <td id="T_e4f4e_row1_col2" class="data row1 col2" >45.6</td>
#       <td id="T_e4f4e_row1_col3" class="data row1 col3" >44.3</td>
#       <td id="T_e4f4e_row1_col4" class="data row1 col4" >0.282</td>
#       <td id="T_e4f4e_row1_col5" class="data row1 col5" >0.441</td>
#       <td id="T_e4f4e_row1_col6" class="data row1 col6" >1.19e+02</td>
#       <td id="T_e4f4e_row1_col7" class="data row1 col7" >25.8</td>
#       <td id="T_e4f4e_row1_col8" class="data row1 col8" >32.1</td>
#       <td id="T_e4f4e_row1_col9" class="data row1 col9" >0.126</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Below 5 m

# %%
idepth = 5
jdepth = 39

number, results = stats_allregions([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
                           [2015, 2016, 2017], [], [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 
                           [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [], 
                           [],
                           idepth, jdepth, 'below5m')
for boxname in boxnames:
    if number > 0:
        print(f'\033[1m{boxname}\033[1m')
        display(results[results.region == boxname].loc[:, results.columns != 'region'].style.format(myformat).apply(highlight_max_min))
# Out:
# SS_all
# <style type="text/css">
# #T_908eb_row0_col0, #T_908eb_row0_col1, #T_908eb_row0_col2, #T_908eb_row0_col3, #T_908eb_row0_col4, #T_908eb_row0_col6, #T_908eb_row0_col7, #T_908eb_row0_col8, #T_908eb_row1_col0, #T_908eb_row1_col5, #T_908eb_row1_col9 {
#   color: red;
# }
# #T_908eb_row0_col5, #T_908eb_row0_col9, #T_908eb_row1_col1, #T_908eb_row1_col2, #T_908eb_row1_col3, #T_908eb_row1_col4, #T_908eb_row1_col6, #T_908eb_row1_col7, #T_908eb_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_908eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_908eb_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_908eb_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_908eb_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_908eb_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_908eb_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_908eb_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_908eb_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_908eb_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_908eb_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_908eb_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_908eb_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_908eb_row0_col0" class="data row0 col0" >887904</td>
#       <td id="T_908eb_row0_col1" class="data row0 col1" >-32.3</td>
#       <td id="T_908eb_row0_col2" class="data row0 col2" >43.5</td>
#       <td id="T_908eb_row0_col3" class="data row0 col3" >29.2</td>
#       <td id="T_908eb_row0_col4" class="data row0 col4" >0.153</td>
#       <td id="T_908eb_row0_col5" class="data row0 col5" >-0.124</td>
#       <td id="T_908eb_row0_col6" class="data row0 col6" >-53.5</td>
#       <td id="T_908eb_row0_col7" class="data row0 col7" >32.9</td>
#       <td id="T_908eb_row0_col8" class="data row0 col8" >30.4</td>
#       <td id="T_908eb_row0_col9" class="data row0 col9" >-0.204</td>
#     </tr>
#     <tr>
#       <th id="T_908eb_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_908eb_row1_col0" class="data row1 col0" >887904</td>
#       <td id="T_908eb_row1_col1" class="data row1 col1" >-3.82</td>
#       <td id="T_908eb_row1_col2" class="data row1 col2" >24.8</td>
#       <td id="T_908eb_row1_col3" class="data row1 col3" >24.5</td>
#       <td id="T_908eb_row1_col4" class="data row1 col4" >0.0702</td>
#       <td id="T_908eb_row1_col5" class="data row1 col5" >0.155</td>
#       <td id="T_908eb_row1_col6" class="data row1 col6" >22.6</td>
#       <td id="T_908eb_row1_col7" class="data row1 col7" >8.83</td>
#       <td id="T_908eb_row1_col8" class="data row1 col8" >21.6</td>
#       <td id="T_908eb_row1_col9" class="data row1 col9" >0.279</td>
#     </tr>
#   </tbody>
# </table>
# SoG_south
# <style type="text/css">
# #T_b8b97_row0_col0, #T_b8b97_row0_col1, #T_b8b97_row0_col2, #T_b8b97_row0_col3, #T_b8b97_row0_col4, #T_b8b97_row0_col5, #T_b8b97_row0_col6, #T_b8b97_row0_col7, #T_b8b97_row0_col8, #T_b8b97_row0_col9, #T_b8b97_row1_col0 {
#   color: red;
# }
# #T_b8b97_row1_col1, #T_b8b97_row1_col2, #T_b8b97_row1_col3, #T_b8b97_row1_col4, #T_b8b97_row1_col5, #T_b8b97_row1_col6, #T_b8b97_row1_col7, #T_b8b97_row1_col8, #T_b8b97_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_b8b97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8b97_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_b8b97_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_b8b97_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_b8b97_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_b8b97_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_b8b97_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_b8b97_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_b8b97_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_b8b97_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_b8b97_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8b97_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_b8b97_row0_col0" class="data row0 col0" >41191</td>
#       <td id="T_b8b97_row0_col1" class="data row0 col1" >-22.8</td>
#       <td id="T_b8b97_row0_col2" class="data row0 col2" >32.4</td>
#       <td id="T_b8b97_row0_col3" class="data row0 col3" >23.0</td>
#       <td id="T_b8b97_row0_col4" class="data row0 col4" >0.114</td>
#       <td id="T_b8b97_row0_col5" class="data row0 col5" >-0.305</td>
#       <td id="T_b8b97_row0_col6" class="data row0 col6" >-84.5</td>
#       <td id="T_b8b97_row0_col7" class="data row0 col7" >26.1</td>
#       <td id="T_b8b97_row0_col8" class="data row0 col8" >22.8</td>
#       <td id="T_b8b97_row0_col9" class="data row0 col9" >-0.624</td>
#     </tr>
#     <tr>
#       <th id="T_b8b97_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_b8b97_row1_col0" class="data row1 col0" >41191</td>
#       <td id="T_b8b97_row1_col1" class="data row1 col1" >-7.07</td>
#       <td id="T_b8b97_row1_col2" class="data row1 col2" >17.4</td>
#       <td id="T_b8b97_row1_col3" class="data row1 col3" >15.8</td>
#       <td id="T_b8b97_row1_col4" class="data row1 col4" >0.0443</td>
#       <td id="T_b8b97_row1_col5" class="data row1 col5" >-0.000644</td>
#       <td id="T_b8b97_row1_col6" class="data row1 col6" >-7.2</td>
#       <td id="T_b8b97_row1_col7" class="data row1 col7" >7.07</td>
#       <td id="T_b8b97_row1_col8" class="data row1 col8" >15.9</td>
#       <td id="T_b8b97_row1_col9" class="data row1 col9" >-0.00284</td>
#     </tr>
#   </tbody>
# </table>
# SoG_center
# <style type="text/css">
# #T_db53c_row0_col0, #T_db53c_row0_col1, #T_db53c_row0_col2, #T_db53c_row0_col3, #T_db53c_row0_col4, #T_db53c_row0_col5, #T_db53c_row0_col6, #T_db53c_row0_col7, #T_db53c_row0_col8, #T_db53c_row0_col9, #T_db53c_row1_col0 {
#   color: red;
# }
# #T_db53c_row1_col1, #T_db53c_row1_col2, #T_db53c_row1_col3, #T_db53c_row1_col4, #T_db53c_row1_col5, #T_db53c_row1_col6, #T_db53c_row1_col7, #T_db53c_row1_col8, #T_db53c_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_db53c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db53c_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_db53c_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_db53c_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_db53c_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_db53c_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_db53c_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_db53c_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_db53c_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_db53c_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_db53c_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db53c_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_db53c_row0_col0" class="data row0 col0" >168207</td>
#       <td id="T_db53c_row0_col1" class="data row0 col1" >-38.5</td>
#       <td id="T_db53c_row0_col2" class="data row0 col2" >45.4</td>
#       <td id="T_db53c_row0_col3" class="data row0 col3" >24.0</td>
#       <td id="T_db53c_row0_col4" class="data row0 col4" >0.198</td>
#       <td id="T_db53c_row0_col5" class="data row0 col5" >-0.209</td>
#       <td id="T_db53c_row0_col6" class="data row0 col6" >-73.6</td>
#       <td id="T_db53c_row0_col7" class="data row0 col7" >39.5</td>
#       <td id="T_db53c_row0_col8" class="data row0 col8" >25.0</td>
#       <td id="T_db53c_row0_col9" class="data row0 col9" >-0.296</td>
#     </tr>
#     <tr>
#       <th id="T_db53c_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_db53c_row1_col0" class="data row1 col0" >168207</td>
#       <td id="T_db53c_row1_col1" class="data row1 col1" >-2.96</td>
#       <td id="T_db53c_row1_col2" class="data row1 col2" >17.6</td>
#       <td id="T_db53c_row1_col3" class="data row1 col3" >17.4</td>
#       <td id="T_db53c_row1_col4" class="data row1 col4" >0.0464</td>
#       <td id="T_db53c_row1_col5" class="data row1 col5" >0.0819</td>
#       <td id="T_db53c_row1_col6" class="data row1 col6" >10.8</td>
#       <td id="T_db53c_row1_col7" class="data row1 col7" >4.61</td>
#       <td id="T_db53c_row1_col8" class="data row1 col8" >16.4</td>
#       <td id="T_db53c_row1_col9" class="data row1 col9" >0.195</td>
#     </tr>
#   </tbody>
# </table>
# SoG_north
# <style type="text/css">
# #T_cb502_row0_col0, #T_cb502_row0_col1, #T_cb502_row0_col2, #T_cb502_row0_col3, #T_cb502_row0_col4, #T_cb502_row0_col6, #T_cb502_row0_col7, #T_cb502_row0_col8, #T_cb502_row1_col0, #T_cb502_row1_col5, #T_cb502_row1_col9 {
#   color: red;
# }
# #T_cb502_row0_col5, #T_cb502_row0_col9, #T_cb502_row1_col1, #T_cb502_row1_col2, #T_cb502_row1_col3, #T_cb502_row1_col4, #T_cb502_row1_col6, #T_cb502_row1_col7, #T_cb502_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_cb502">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb502_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_cb502_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_cb502_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_cb502_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_cb502_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_cb502_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_cb502_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_cb502_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_cb502_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_cb502_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb502_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_cb502_row0_col0" class="data row0 col0" >76319</td>
#       <td id="T_cb502_row0_col1" class="data row0 col1" >-44.5</td>
#       <td id="T_cb502_row0_col2" class="data row0 col2" >49.5</td>
#       <td id="T_cb502_row0_col3" class="data row0 col3" >21.7</td>
#       <td id="T_cb502_row0_col4" class="data row0 col4" >0.224</td>
#       <td id="T_cb502_row0_col5" class="data row0 col5" >-0.095</td>
#       <td id="T_cb502_row0_col6" class="data row0 col6" >-60.1</td>
#       <td id="T_cb502_row0_col7" class="data row0 col7" >44.7</td>
#       <td id="T_cb502_row0_col8" class="data row0 col8" >22.3</td>
#       <td id="T_cb502_row0_col9" class="data row0 col9" >-0.201</td>
#     </tr>
#     <tr>
#       <th id="T_cb502_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_cb502_row1_col0" class="data row1 col0" >76319</td>
#       <td id="T_cb502_row1_col1" class="data row1 col1" >-1.62</td>
#       <td id="T_cb502_row1_col2" class="data row1 col2" >20.5</td>
#       <td id="T_cb502_row1_col3" class="data row1 col3" >20.4</td>
#       <td id="T_cb502_row1_col4" class="data row1 col4" >0.0681</td>
#       <td id="T_cb502_row1_col5" class="data row1 col5" >0.247</td>
#       <td id="T_cb502_row1_col6" class="data row1 col6" >38.8</td>
#       <td id="T_cb502_row1_col7" class="data row1 col7" >11.2</td>
#       <td id="T_cb502_row1_col8" class="data row1 col8" >15.4</td>
#       <td id="T_cb502_row1_col9" class="data row1 col9" >0.387</td>
#     </tr>
#   </tbody>
# </table>
# Haro_Boundary
# <style type="text/css">
# #T_e2723_row0_col0, #T_e2723_row0_col1, #T_e2723_row0_col2, #T_e2723_row0_col3, #T_e2723_row0_col4, #T_e2723_row0_col6, #T_e2723_row0_col7, #T_e2723_row0_col8, #T_e2723_row1_col0, #T_e2723_row1_col5, #T_e2723_row1_col9 {
#   color: red;
# }
# #T_e2723_row0_col5, #T_e2723_row0_col9, #T_e2723_row1_col1, #T_e2723_row1_col2, #T_e2723_row1_col3, #T_e2723_row1_col4, #T_e2723_row1_col6, #T_e2723_row1_col7, #T_e2723_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_e2723">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2723_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_e2723_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_e2723_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_e2723_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_e2723_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_e2723_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_e2723_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_e2723_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_e2723_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_e2723_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2723_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_e2723_row0_col0" class="data row0 col0" >6125</td>
#       <td id="T_e2723_row0_col1" class="data row0 col1" >-30.7</td>
#       <td id="T_e2723_row0_col2" class="data row0 col2" >45.6</td>
#       <td id="T_e2723_row0_col3" class="data row0 col3" >33.7</td>
#       <td id="T_e2723_row0_col4" class="data row0 col4" >0.197</td>
#       <td id="T_e2723_row0_col5" class="data row0 col5" >-0.108</td>
#       <td id="T_e2723_row0_col6" class="data row0 col6" >-51.9</td>
#       <td id="T_e2723_row0_col7" class="data row0 col7" >31.1</td>
#       <td id="T_e2723_row0_col8" class="data row0 col8" >35.2</td>
#       <td id="T_e2723_row0_col9" class="data row0 col9" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_e2723_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_e2723_row1_col0" class="data row1 col0" >6125</td>
#       <td id="T_e2723_row1_col1" class="data row1 col1" >-13.5</td>
#       <td id="T_e2723_row1_col2" class="data row1 col2" >30.6</td>
#       <td id="T_e2723_row1_col3" class="data row1 col3" >27.4</td>
#       <td id="T_e2723_row1_col4" class="data row1 col4" >0.125</td>
#       <td id="T_e2723_row1_col5" class="data row1 col5" >0.223</td>
#       <td id="T_e2723_row1_col6" class="data row1 col6" >30.4</td>
#       <td id="T_e2723_row1_col7" class="data row1 col7" >17.3</td>
#       <td id="T_e2723_row1_col8" class="data row1 col8" >22.8</td>
#       <td id="T_e2723_row1_col9" class="data row1 col9" >0.384</td>
#     </tr>
#   </tbody>
# </table>
# JdF_west
# <style type="text/css">
# #T_6240f_row0_col0, #T_6240f_row0_col1, #T_6240f_row0_col2, #T_6240f_row0_col3, #T_6240f_row0_col4, #T_6240f_row0_col5, #T_6240f_row0_col6, #T_6240f_row0_col7, #T_6240f_row0_col8, #T_6240f_row0_col9, #T_6240f_row1_col0 {
#   color: red;
# }
# #T_6240f_row1_col1, #T_6240f_row1_col2, #T_6240f_row1_col3, #T_6240f_row1_col4, #T_6240f_row1_col5, #T_6240f_row1_col6, #T_6240f_row1_col7, #T_6240f_row1_col8, #T_6240f_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_6240f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6240f_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_6240f_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_6240f_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_6240f_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_6240f_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_6240f_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_6240f_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_6240f_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_6240f_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_6240f_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6240f_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_6240f_row0_col0" class="data row0 col0" >50180</td>
#       <td id="T_6240f_row0_col1" class="data row0 col1" >-9.91</td>
#       <td id="T_6240f_row0_col2" class="data row0 col2" >19.4</td>
#       <td id="T_6240f_row0_col3" class="data row0 col3" >16.7</td>
#       <td id="T_6240f_row0_col4" class="data row0 col4" >0.0463</td>
#       <td id="T_6240f_row0_col5" class="data row0 col5" >-0.125</td>
#       <td id="T_6240f_row0_col6" class="data row0 col6" >-33.2</td>
#       <td id="T_6240f_row0_col7" class="data row0 col7" >11.3</td>
#       <td id="T_6240f_row0_col8" class="data row0 col8" >16.9</td>
#       <td id="T_6240f_row0_col9" class="data row0 col9" >-0.252</td>
#     </tr>
#     <tr>
#       <th id="T_6240f_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_6240f_row1_col0" class="data row1 col0" >50180</td>
#       <td id="T_6240f_row1_col1" class="data row1 col1" >-5.99</td>
#       <td id="T_6240f_row1_col2" class="data row1 col2" >15.8</td>
#       <td id="T_6240f_row1_col3" class="data row1 col3" >14.7</td>
#       <td id="T_6240f_row1_col4" class="data row1 col4" >0.0331</td>
#       <td id="T_6240f_row1_col5" class="data row1 col5" >-0.0465</td>
#       <td id="T_6240f_row1_col6" class="data row1 col6" >-14.7</td>
#       <td id="T_6240f_row1_col7" class="data row1 col7" >6.32</td>
#       <td id="T_6240f_row1_col8" class="data row1 col8" >14.9</td>
#       <td id="T_6240f_row1_col9" class="data row1 col9" >-0.0903</td>
#     </tr>
#   </tbody>
# </table>
# JdF_east
# <style type="text/css">
# #T_e7144_row0_col0, #T_e7144_row0_col2, #T_e7144_row0_col3, #T_e7144_row0_col4, #T_e7144_row0_col6, #T_e7144_row0_col8, #T_e7144_row1_col0, #T_e7144_row1_col1, #T_e7144_row1_col5, #T_e7144_row1_col7, #T_e7144_row1_col9 {
#   color: red;
# }
# #T_e7144_row0_col1, #T_e7144_row0_col5, #T_e7144_row0_col7, #T_e7144_row0_col9, #T_e7144_row1_col2, #T_e7144_row1_col3, #T_e7144_row1_col4, #T_e7144_row1_col6, #T_e7144_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_e7144">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7144_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_e7144_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_e7144_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_e7144_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_e7144_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_e7144_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_e7144_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_e7144_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_e7144_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_e7144_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7144_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_e7144_row0_col0" class="data row0 col0" >37286</td>
#       <td id="T_e7144_row0_col1" class="data row0 col1" >-9.11</td>
#       <td id="T_e7144_row0_col2" class="data row0 col2" >25.4</td>
#       <td id="T_e7144_row0_col3" class="data row0 col3" >23.7</td>
#       <td id="T_e7144_row0_col4" class="data row0 col4" >0.0456</td>
#       <td id="T_e7144_row0_col5" class="data row0 col5" >0.0135</td>
#       <td id="T_e7144_row0_col6" class="data row0 col6" >-7.08</td>
#       <td id="T_e7144_row0_col7" class="data row0 col7" >9.14</td>
#       <td id="T_e7144_row0_col8" class="data row0 col8" >23.5</td>
#       <td id="T_e7144_row0_col9" class="data row0 col9" >0.00628</td>
#     </tr>
#     <tr>
#       <th id="T_e7144_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_e7144_row1_col0" class="data row1 col0" >37286</td>
#       <td id="T_e7144_row1_col1" class="data row1 col1" >-9.29</td>
#       <td id="T_e7144_row1_col2" class="data row1 col2" >23.4</td>
#       <td id="T_e7144_row1_col3" class="data row1 col3" >21.5</td>
#       <td id="T_e7144_row1_col4" class="data row1 col4" >0.0387</td>
#       <td id="T_e7144_row1_col5" class="data row1 col5" >0.0156</td>
#       <td id="T_e7144_row1_col6" class="data row1 col6" >-6.95</td>
#       <td id="T_e7144_row1_col7" class="data row1 col7" >9.34</td>
#       <td id="T_e7144_row1_col8" class="data row1 col8" >21.3</td>
#       <td id="T_e7144_row1_col9" class="data row1 col9" >0.0201</td>
#     </tr>
#   </tbody>
# </table>
# PS_main
# <style type="text/css">
# #T_f9fcc_row0_col0, #T_f9fcc_row0_col1, #T_f9fcc_row0_col2, #T_f9fcc_row0_col3, #T_f9fcc_row0_col4, #T_f9fcc_row0_col7, #T_f9fcc_row0_col8, #T_f9fcc_row1_col0, #T_f9fcc_row1_col5, #T_f9fcc_row1_col6, #T_f9fcc_row1_col9 {
#   color: red;
# }
# #T_f9fcc_row0_col5, #T_f9fcc_row0_col6, #T_f9fcc_row0_col9, #T_f9fcc_row1_col1, #T_f9fcc_row1_col2, #T_f9fcc_row1_col3, #T_f9fcc_row1_col4, #T_f9fcc_row1_col7, #T_f9fcc_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_f9fcc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9fcc_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_f9fcc_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_f9fcc_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_f9fcc_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_f9fcc_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_f9fcc_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_f9fcc_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_f9fcc_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_f9fcc_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_f9fcc_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9fcc_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_f9fcc_row0_col0" class="data row0 col0" >30036</td>
#       <td id="T_f9fcc_row0_col1" class="data row0 col1" >-10.1</td>
#       <td id="T_f9fcc_row0_col2" class="data row0 col2" >21.3</td>
#       <td id="T_f9fcc_row0_col3" class="data row0 col3" >18.8</td>
#       <td id="T_f9fcc_row0_col4" class="data row0 col4" >0.0444</td>
#       <td id="T_f9fcc_row0_col5" class="data row0 col5" >0.0401</td>
#       <td id="T_f9fcc_row0_col6" class="data row0 col6" >-2.92</td>
#       <td id="T_f9fcc_row0_col7" class="data row0 col7" >10.3</td>
#       <td id="T_f9fcc_row0_col8" class="data row0 col8" >18.3</td>
#       <td id="T_f9fcc_row0_col9" class="data row0 col9" >0.0718</td>
#     </tr>
#     <tr>
#       <th id="T_f9fcc_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_f9fcc_row1_col0" class="data row1 col0" >30036</td>
#       <td id="T_f9fcc_row1_col1" class="data row1 col1" >-9.29</td>
#       <td id="T_f9fcc_row1_col2" class="data row1 col2" >19.5</td>
#       <td id="T_f9fcc_row1_col3" class="data row1 col3" >17.2</td>
#       <td id="T_f9fcc_row1_col4" class="data row1 col4" >0.0383</td>
#       <td id="T_f9fcc_row1_col5" class="data row1 col5" >0.0751</td>
#       <td id="T_f9fcc_row1_col6" class="data row1 col6" >4.17</td>
#       <td id="T_f9fcc_row1_col7" class="data row1 col7" >10.1</td>
#       <td id="T_f9fcc_row1_col8" class="data row1 col8" >16.1</td>
#       <td id="T_f9fcc_row1_col9" class="data row1 col9" >0.137</td>
#     </tr>
#   </tbody>
# </table>
# Hood_Canal
# <style type="text/css">
# #T_d94a8_row0_col0, #T_d94a8_row0_col2, #T_d94a8_row0_col3, #T_d94a8_row0_col8, #T_d94a8_row1_col0, #T_d94a8_row1_col1, #T_d94a8_row1_col4, #T_d94a8_row1_col5, #T_d94a8_row1_col6, #T_d94a8_row1_col7, #T_d94a8_row1_col9 {
#   color: red;
# }
# #T_d94a8_row0_col1, #T_d94a8_row0_col4, #T_d94a8_row0_col5, #T_d94a8_row0_col6, #T_d94a8_row0_col7, #T_d94a8_row0_col9, #T_d94a8_row1_col2, #T_d94a8_row1_col3, #T_d94a8_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_d94a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d94a8_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_d94a8_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_d94a8_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_d94a8_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_d94a8_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_d94a8_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_d94a8_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_d94a8_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_d94a8_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_d94a8_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d94a8_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_d94a8_row0_col0" class="data row0 col0" >818</td>
#       <td id="T_d94a8_row0_col1" class="data row0 col1" >-1.93</td>
#       <td id="T_d94a8_row0_col2" class="data row0 col2" >56.0</td>
#       <td id="T_d94a8_row0_col3" class="data row0 col3" >55.9</td>
#       <td id="T_d94a8_row0_col4" class="data row0 col4" >0.116</td>
#       <td id="T_d94a8_row0_col5" class="data row0 col5" >0.109</td>
#       <td id="T_d94a8_row0_col6" class="data row0 col6" >15.5</td>
#       <td id="T_d94a8_row0_col7" class="data row0 col7" >10.0</td>
#       <td id="T_d94a8_row0_col8" class="data row0 col8" >52.3</td>
#       <td id="T_d94a8_row0_col9" class="data row0 col9" >0.168</td>
#     </tr>
#     <tr>
#       <th id="T_d94a8_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_d94a8_row1_col0" class="data row1 col0" >818</td>
#       <td id="T_d94a8_row1_col1" class="data row1 col1" >-2.43</td>
#       <td id="T_d94a8_row1_col2" class="data row1 col2" >55.3</td>
#       <td id="T_d94a8_row1_col3" class="data row1 col3" >55.2</td>
#       <td id="T_d94a8_row1_col4" class="data row1 col4" >0.15</td>
#       <td id="T_d94a8_row1_col5" class="data row1 col5" >0.409</td>
#       <td id="T_d94a8_row1_col6" class="data row1 col6" >62.7</td>
#       <td id="T_d94a8_row1_col7" class="data row1 col7" >36.7</td>
#       <td id="T_d94a8_row1_col8" class="data row1 col8" >35.4</td>
#       <td id="T_d94a8_row1_col9" class="data row1 col9" >0.575</td>
#     </tr>
#   </tbody>
# </table>
# Saanich_Inlet
# <style type="text/css">
# #T_42185_row0_col0, #T_42185_row0_col8, #T_42185_row1_col0, #T_42185_row1_col1, #T_42185_row1_col2, #T_42185_row1_col3, #T_42185_row1_col4, #T_42185_row1_col5, #T_42185_row1_col6, #T_42185_row1_col7, #T_42185_row1_col9 {
#   color: red;
# }
# #T_42185_row0_col1, #T_42185_row0_col2, #T_42185_row0_col3, #T_42185_row0_col4, #T_42185_row0_col5, #T_42185_row0_col6, #T_42185_row0_col7, #T_42185_row0_col9, #T_42185_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_42185">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42185_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_42185_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_42185_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_42185_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_42185_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_42185_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_42185_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_42185_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_42185_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_42185_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42185_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_42185_row0_col0" class="data row0 col0" >21306</td>
#       <td id="T_42185_row0_col1" class="data row0 col1" >23.9</td>
#       <td id="T_42185_row0_col2" class="data row0 col2" >67.0</td>
#       <td id="T_42185_row0_col3" class="data row0 col3" >62.6</td>
#       <td id="T_42185_row0_col4" class="data row0 col4" >0.211</td>
#       <td id="T_42185_row0_col5" class="data row0 col5" >0.468</td>
#       <td id="T_42185_row0_col6" class="data row0 col6" >92.6</td>
#       <td id="T_42185_row0_col7" class="data row0 col7" >49.3</td>
#       <td id="T_42185_row0_col8" class="data row0 col8" >38.5</td>
#       <td id="T_42185_row0_col9" class="data row0 col9" >0.644</td>
#     </tr>
#     <tr>
#       <th id="T_42185_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_42185_row1_col0" class="data row1 col0" >21306</td>
#       <td id="T_42185_row1_col1" class="data row1 col1" >43.0</td>
#       <td id="T_42185_row1_col2" class="data row1 col2" >77.9</td>
#       <td id="T_42185_row1_col3" class="data row1 col3" >65.0</td>
#       <td id="T_42185_row1_col4" class="data row1 col4" >0.295</td>
#       <td id="T_42185_row1_col5" class="data row1 col5" >0.605</td>
#       <td id="T_42185_row1_col6" class="data row1 col6" >1.32e+02</td>
#       <td id="T_42185_row1_col7" class="data row1 col7" >70.4</td>
#       <td id="T_42185_row1_col8" class="data row1 col8" >28.0</td>
#       <td id="T_42185_row1_col9" class="data row1 col9" >0.792</td>
#     </tr>
#   </tbody>
# </table>
# Fraser_plume
# <style type="text/css">
# #T_0567a_row0_col0, #T_0567a_row0_col1, #T_0567a_row0_col2, #T_0567a_row0_col3, #T_0567a_row0_col4, #T_0567a_row0_col5, #T_0567a_row0_col6, #T_0567a_row0_col7, #T_0567a_row0_col8, #T_0567a_row0_col9, #T_0567a_row1_col0 {
#   color: red;
# }
# #T_0567a_row1_col1, #T_0567a_row1_col2, #T_0567a_row1_col3, #T_0567a_row1_col4, #T_0567a_row1_col5, #T_0567a_row1_col6, #T_0567a_row1_col7, #T_0567a_row1_col8, #T_0567a_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_0567a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0567a_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_0567a_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_0567a_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_0567a_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_0567a_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_0567a_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_0567a_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_0567a_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_0567a_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_0567a_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0567a_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_0567a_row0_col0" class="data row0 col0" >107523</td>
#       <td id="T_0567a_row0_col1" class="data row0 col1" >-34.0</td>
#       <td id="T_0567a_row0_col2" class="data row0 col2" >42.6</td>
#       <td id="T_0567a_row0_col3" class="data row0 col3" >25.6</td>
#       <td id="T_0567a_row0_col4" class="data row0 col4" >0.175</td>
#       <td id="T_0567a_row0_col5" class="data row0 col5" >-0.289</td>
#       <td id="T_0567a_row0_col6" class="data row0 col6" >-85.8</td>
#       <td id="T_0567a_row0_col7" class="data row0 col7" >36.2</td>
#       <td id="T_0567a_row0_col8" class="data row0 col8" >26.4</td>
#       <td id="T_0567a_row0_col9" class="data row0 col9" >-0.621</td>
#     </tr>
#     <tr>
#       <th id="T_0567a_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_0567a_row1_col0" class="data row1 col0" >107523</td>
#       <td id="T_0567a_row1_col1" class="data row1 col1" >-4.05</td>
#       <td id="T_0567a_row1_col2" class="data row1 col2" >19.4</td>
#       <td id="T_0567a_row1_col3" class="data row1 col3" >19.0</td>
#       <td id="T_0567a_row1_col4" class="data row1 col4" >0.054</td>
#       <td id="T_0567a_row1_col5" class="data row1 col5" >0.0216</td>
#       <td id="T_0567a_row1_col6" class="data row1 col6" >-0.182</td>
#       <td id="T_0567a_row1_col7" class="data row1 col7" >4.16</td>
#       <td id="T_0567a_row1_col8" class="data row1 col8" >18.8</td>
#       <td id="T_0567a_row1_col9" class="data row1 col9" >0.0343</td>
#     </tr>
#   </tbody>
# </table>
